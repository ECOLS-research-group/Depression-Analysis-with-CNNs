# %% [markdown]
# Contents of main.py

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from model import CNN_GSGD, GSGDOptimizer
from train import train, test
import os
import torch.nn as nn
from torch.utils.data import random_split

# %% [markdown]
# # Data loading, model setup, and main training loop code here

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# %% [markdown]
# HISTOGRAM

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import zipfile
import os

# Path to the ZIP file
zip_file_path = '/content/drive/My Drive/Soft Computing Resources/AlgX3_64x64_merged_tensors_with_labels.zip'
extract_path = '/content/'

# Verify if the ZIP file exists
if not os.path.exists(zip_file_path):
    raise FileNotFoundError(f"File not found: {zip_file_path}")

# Copy the ZIP file to Colab
# !cp "{zip_file_path}" /content

# Unzip the file
with zipfile.ZipFile('/content/AlgX3_64x64_merged_tensors_with_labels.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# Mounted at /content/drive

# %%
# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the path to the folder where your images are stored
data_path = '/content/AlgX3_64x64_merged_tensors_with_labels'  # Update this with the path to your images

# Step 1: Set up transformations (similar to MNIST preprocessing)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale if needed
    # transforms.Resize((28, 28)),  # Resize to 28x28 to match MNIST dimensions, adjust if needed
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to match MNIST-like preprocessing
])

# Step 2: Load the entire dataset using ImageFolder
full_dataset = datasets.ImageFolder(root=data_path, transform=transform)

# Step 3: Get input size dynamically from the first image in the dataset
sample_image, _ = full_dataset[0]  # Take the first image to determine the input shape
input_size = sample_image.shape  # This will be (C, H, W)

# Step 4: Split the dataset into training and testing sets
train_size = int(0.8 * len(full_dataset))  # 80% for training
test_size = len(full_dataset) - train_size  # Remaining 20% for testing
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

# Step 5: Create DataLoaders for both sets
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Split the train_dataset into training and validation datasets
train_size = int(0.8 * len(train_dataset))  # 80% for training
validation_size = len(train_dataset) - train_size  # Remaining 20% for validation
train_dataset, validation_dataset = random_split(train_dataset, [train_size, validation_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)
validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN_GSGD(input_size=input_size, num_classes=len(full_dataset.classes)).to(device)

# model = EnhancedCNN_GSGD(num_classes=len(full_dataset.classes)).to(device)


# For Standard Guided SGD
# optimizer = GSGDOptimizer(model.parameters(), lr=0.01, method='sgd')

# For Guided SGD with Momentum
optimizer = GSGDOptimizer(model.parameters(), lr=0.01, method='momentum', momentum=0.9)

# For Guided Adam
# optimizer = GSGDOptimizer(model.parameters(), lr=0.001, method='adam', beta1=0.9, beta2=0.999)

# %%
# Define the loss function
loss_fn = nn.CrossEntropyLoss()

# Run training for each epoch, passing the dataset instead of DataLoader
for epoch in range(1, 30):
    train(model, device, train_loader.dataset, validation_loader.dataset, optimizer, epoch, loss_fn,
      verification_set_num=4, rho=10, log_interval=9)
    # train(model, device, train_loader.dataset, optimizer, epoch, loss_fn)  # Pass train_loader.dataset
    test(model, device, test_loader)
# Out:
# Epoch: 1, Iteration: 1, Loss: 0.694645
# Epoch: 1, Iteration: 10, Loss: 0.670210
# Epoch: 1, Iteration: 19, Loss: 0.585004
# Epoch: 1, Iteration: 28, Loss: 0.443902
# Epoch: 1, Iteration: 37, Loss: 0.504881
# Epoch: 1, Iteration: 46, Loss: 0.462726
# Epoch: 1, Iteration: 55, Loss: 0.500836
# Epoch: 1, Iteration: 64, Loss: 0.603422
# Epoch: 1, Iteration: 73, Loss: 0.312216
# Epoch 1 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1277/1547 (83%)
#
# Epoch: 2, Iteration: 1, Loss: 0.563762
# Epoch: 2, Iteration: 10, Loss: 0.467591
# Epoch: 2, Iteration: 19, Loss: 0.514833
# Epoch: 2, Iteration: 28, Loss: 0.432840
# Epoch: 2, Iteration: 37, Loss: 0.454269
# Epoch: 2, Iteration: 46, Loss: 0.432282
# Epoch: 2, Iteration: 55, Loss: 0.321055
# Epoch: 2, Iteration: 64, Loss: 0.325635
# Epoch: 2, Iteration: 73, Loss: 0.289064
# Epoch 2 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1313/1547 (85%)
#
# Epoch: 3, Iteration: 1, Loss: 0.285654
# Epoch: 3, Iteration: 10, Loss: 0.372033
# Epoch: 3, Iteration: 19, Loss: 0.388949
# Epoch: 3, Iteration: 28, Loss: 0.239885
# Epoch: 3, Iteration: 37, Loss: 0.418544
# Epoch: 3, Iteration: 46, Loss: 0.380271
# Epoch: 3, Iteration: 55, Loss: 0.444142
# Epoch: 3, Iteration: 64, Loss: 0.322853
# Epoch: 3, Iteration: 73, Loss: 0.480072
# Epoch 3 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1337/1547 (86%)
#
# Epoch: 4, Iteration: 1, Loss: 0.348348
# Epoch: 4, Iteration: 10, Loss: 0.341288
# Epoch: 4, Iteration: 19, Loss: 0.375464
# Epoch: 4, Iteration: 28, Loss: 0.278443
# Epoch: 4, Iteration: 37, Loss: 0.366493
# Epoch: 4, Iteration: 46, Loss: 0.208303
# Epoch: 4, Iteration: 55, Loss: 0.316659
# Epoch: 4, Iteration: 64, Loss: 0.362660
# Epoch: 4, Iteration: 73, Loss: 0.230330
# Epoch 4 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1339/1547 (87%)
#
# Epoch: 5, Iteration: 1, Loss: 0.326340
# Epoch: 5, Iteration: 10, Loss: 0.361621
# Epoch: 5, Iteration: 19, Loss: 0.307756
# Epoch: 5, Iteration: 28, Loss: 0.204460
# Epoch: 5, Iteration: 37, Loss: 0.113492
# Epoch: 5, Iteration: 46, Loss: 0.355856
# Epoch: 5, Iteration: 55, Loss: 0.410386
# Epoch: 5, Iteration: 64, Loss: 0.247361
# Epoch: 5, Iteration: 73, Loss: 0.316909
# Epoch 5 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1337/1547 (86%)
#
# Epoch: 6, Iteration: 1, Loss: 0.396018
# Epoch: 6, Iteration: 10, Loss: 0.287751
# Epoch: 6, Iteration: 19, Loss: 0.386249
# Epoch: 6, Iteration: 28, Loss: 0.199578
# Epoch: 6, Iteration: 37, Loss: 0.299069
# Epoch: 6, Iteration: 46, Loss: 0.227748
# Epoch: 6, Iteration: 55, Loss: 0.278826
# Epoch: 6, Iteration: 64, Loss: 0.328931
# Epoch: 6, Iteration: 73, Loss: 0.251975
# Epoch 6 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1375/1547 (89%)
#
# Epoch: 7, Iteration: 1, Loss: 0.180859
# Epoch: 7, Iteration: 10, Loss: 0.242032
# Epoch: 7, Iteration: 19, Loss: 0.261655
# Epoch: 7, Iteration: 28, Loss: 0.271650
# Epoch: 7, Iteration: 37, Loss: 0.285408
# Epoch: 7, Iteration: 46, Loss: 0.255440
# Epoch: 7, Iteration: 55, Loss: 0.351730
# Epoch: 7, Iteration: 64, Loss: 0.206998
# Epoch: 7, Iteration: 73, Loss: 0.250701
# Epoch 7 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1392/1547 (90%)
#
# Epoch: 8, Iteration: 1, Loss: 0.353998
# Epoch: 8, Iteration: 10, Loss: 0.211940
# Epoch: 8, Iteration: 19, Loss: 0.279980
# Epoch: 8, Iteration: 28, Loss: 0.130530
# Epoch: 8, Iteration: 37, Loss: 0.262407
# Epoch: 8, Iteration: 46, Loss: 0.280294
# Epoch: 8, Iteration: 55, Loss: 0.307032
# Epoch: 8, Iteration: 64, Loss: 0.382023
# Epoch: 8, Iteration: 73, Loss: 0.334068
# Epoch 8 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1389/1547 (90%)
#
# Epoch: 9, Iteration: 1, Loss: 0.329595
# Epoch: 9, Iteration: 10, Loss: 0.118571
# Epoch: 9, Iteration: 19, Loss: 0.461552
# Epoch: 9, Iteration: 28, Loss: 0.264716
# Epoch: 9, Iteration: 37, Loss: 0.253063
# Epoch: 9, Iteration: 46, Loss: 0.270210
# Epoch: 9, Iteration: 55, Loss: 0.235182
# Epoch: 9, Iteration: 64, Loss: 0.258565
# Epoch: 9, Iteration: 73, Loss: 0.111006
# Epoch 9 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1399/1547 (90%)
#
# Epoch: 10, Iteration: 1, Loss: 0.224118
# Epoch: 10, Iteration: 10, Loss: 0.257641
# Epoch: 10, Iteration: 19, Loss: 0.325663
# Epoch: 10, Iteration: 28, Loss: 0.208877
# Epoch: 10, Iteration: 37, Loss: 0.302823
# Epoch: 10, Iteration: 46, Loss: 0.125891
# Epoch: 10, Iteration: 55, Loss: 0.156497
# Epoch: 10, Iteration: 64, Loss: 0.179199
# Epoch: 10, Iteration: 73, Loss: 0.306030
# Epoch 10 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1388/1547 (90%)
#
# Epoch: 11, Iteration: 1, Loss: 0.249402
# Epoch: 11, Iteration: 10, Loss: 0.262508
# Epoch: 11, Iteration: 19, Loss: 0.182995
# Epoch: 11, Iteration: 28, Loss: 0.223466
# Epoch: 11, Iteration: 37, Loss: 0.231935
# Epoch: 11, Iteration: 46, Loss: 0.244052
# Epoch: 11, Iteration: 55, Loss: 0.231906
# Epoch: 11, Iteration: 64, Loss: 0.210426
# Epoch: 11, Iteration: 73, Loss: 0.287761
# Epoch 11 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1404/1547 (91%)
#
# Epoch: 12, Iteration: 1, Loss: 0.345238
# Epoch: 12, Iteration: 10, Loss: 0.211321
# Epoch: 12, Iteration: 19, Loss: 0.242445
# Epoch: 12, Iteration: 28, Loss: 0.331704
# Epoch: 12, Iteration: 37, Loss: 0.278617
# Epoch: 12, Iteration: 46, Loss: 0.258726
# Epoch: 12, Iteration: 55, Loss: 0.335643
# Epoch: 12, Iteration: 64, Loss: 0.181471
# Epoch: 12, Iteration: 73, Loss: 0.225565
# Epoch 12 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1400/1547 (90%)
#
# Epoch: 13, Iteration: 1, Loss: 0.295651
# Epoch: 13, Iteration: 10, Loss: 0.195081
# Epoch: 13, Iteration: 19, Loss: 0.284665
# Epoch: 13, Iteration: 28, Loss: 0.229068
# Epoch: 13, Iteration: 37, Loss: 0.187227
# Epoch: 13, Iteration: 46, Loss: 0.138654
# Epoch: 13, Iteration: 55, Loss: 0.257363
# Epoch: 13, Iteration: 64, Loss: 0.196132
# Epoch: 13, Iteration: 73, Loss: 0.310246
# Epoch 13 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1406/1547 (91%)
#
# Epoch: 14, Iteration: 1, Loss: 0.274540
# Epoch: 14, Iteration: 10, Loss: 0.213113
# Epoch: 14, Iteration: 19, Loss: 0.274849
# Epoch: 14, Iteration: 28, Loss: 0.190197
# Epoch: 14, Iteration: 37, Loss: 0.200672
# Epoch: 14, Iteration: 46, Loss: 0.162775
# Epoch: 14, Iteration: 55, Loss: 0.175139
# Epoch: 14, Iteration: 64, Loss: 0.330363
# Epoch: 14, Iteration: 73, Loss: 0.125827
# Epoch 14 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1411/1547 (91%)
#
# Epoch: 15, Iteration: 1, Loss: 0.279525
# Epoch: 15, Iteration: 10, Loss: 0.238896
# Epoch: 15, Iteration: 19, Loss: 0.144328
# Epoch: 15, Iteration: 28, Loss: 0.392500
# Epoch: 15, Iteration: 37, Loss: 0.237707
# Epoch: 15, Iteration: 46, Loss: 0.173931
# Epoch: 15, Iteration: 55, Loss: 0.137364
# Epoch: 15, Iteration: 64, Loss: 0.202644
# Epoch: 15, Iteration: 73, Loss: 0.160672
# Epoch 15 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1405/1547 (91%)
#
# Epoch: 16, Iteration: 1, Loss: 0.336179
# Epoch: 16, Iteration: 10, Loss: 0.060744
# Epoch: 16, Iteration: 19, Loss: 0.203701
# Epoch: 16, Iteration: 28, Loss: 0.221332
# Epoch: 16, Iteration: 37, Loss: 0.177383
# Epoch: 16, Iteration: 46, Loss: 0.096071
# Epoch: 16, Iteration: 55, Loss: 0.278604
# Epoch: 16, Iteration: 64, Loss: 0.313052
# Epoch: 16, Iteration: 73, Loss: 0.347565
# Epoch 16 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1413/1547 (91%)
#
# Epoch: 17, Iteration: 1, Loss: 0.202585
# Epoch: 17, Iteration: 10, Loss: 0.188517
# Epoch: 17, Iteration: 19, Loss: 0.180396
# Epoch: 17, Iteration: 28, Loss: 0.222420
# Epoch: 17, Iteration: 37, Loss: 0.197554
# Epoch: 17, Iteration: 46, Loss: 0.330406
# Epoch: 17, Iteration: 55, Loss: 0.245891
# Epoch: 17, Iteration: 64, Loss: 0.309270
# Epoch: 17, Iteration: 73, Loss: 0.127509
# Epoch 17 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1405/1547 (91%)
#
# Epoch: 18, Iteration: 1, Loss: 0.204487
# Epoch: 18, Iteration: 10, Loss: 0.212769
# Epoch: 18, Iteration: 19, Loss: 0.146016
# Epoch: 18, Iteration: 28, Loss: 0.175458
# Epoch: 18, Iteration: 37, Loss: 0.094204
# Epoch: 18, Iteration: 46, Loss: 0.138000
# Epoch: 18, Iteration: 55, Loss: 0.093282
# Epoch: 18, Iteration: 64, Loss: 0.352552
# Epoch: 18, Iteration: 73, Loss: 0.129504
# Epoch 18 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1411/1547 (91%)
#
# Epoch: 19, Iteration: 1, Loss: 0.220957
# Epoch: 19, Iteration: 10, Loss: 0.375528
# Epoch: 19, Iteration: 19, Loss: 0.108829
# Epoch: 19, Iteration: 28, Loss: 0.255448
# Epoch: 19, Iteration: 37, Loss: 0.170069
# Epoch: 19, Iteration: 46, Loss: 0.247121
# Epoch: 19, Iteration: 55, Loss: 0.194564
# Epoch: 19, Iteration: 64, Loss: 0.237846
# Epoch: 19, Iteration: 73, Loss: 0.292776
# Epoch 19 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1412/1547 (91%)
#
# Epoch: 20, Iteration: 1, Loss: 0.162956
# Epoch: 20, Iteration: 10, Loss: 0.171595
# Epoch: 20, Iteration: 19, Loss: 0.102273
# Epoch: 20, Iteration: 28, Loss: 0.227851
# Epoch: 20, Iteration: 37, Loss: 0.239657
# Epoch: 20, Iteration: 46, Loss: 0.083417
# Epoch: 20, Iteration: 55, Loss: 0.136268
# Epoch: 20, Iteration: 64, Loss: 0.120768
# Epoch: 20, Iteration: 73, Loss: 0.135943
# Epoch 20 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1417/1547 (92%)
#
# Epoch: 21, Iteration: 1, Loss: 0.241143
# Epoch: 21, Iteration: 10, Loss: 0.227111
# Epoch: 21, Iteration: 19, Loss: 0.145593
# Epoch: 21, Iteration: 28, Loss: 0.199033
# Epoch: 21, Iteration: 37, Loss: 0.114284
# Epoch: 21, Iteration: 46, Loss: 0.241719
# Epoch: 21, Iteration: 55, Loss: 0.290704
# Epoch: 21, Iteration: 64, Loss: 0.217476
# Epoch: 21, Iteration: 73, Loss: 0.209869
# Epoch 21 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1412/1547 (91%)
#
# Epoch: 22, Iteration: 1, Loss: 0.201757
# Epoch: 22, Iteration: 10, Loss: 0.141328
# Epoch: 22, Iteration: 19, Loss: 0.172218
# Epoch: 22, Iteration: 28, Loss: 0.153047
# Epoch: 22, Iteration: 37, Loss: 0.134955
# Epoch: 22, Iteration: 46, Loss: 0.295501
# Epoch: 22, Iteration: 55, Loss: 0.346629
# Epoch: 22, Iteration: 64, Loss: 0.126647
# Epoch: 22, Iteration: 73, Loss: 0.422235
# Epoch 22 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1410/1547 (91%)
#
# Epoch: 23, Iteration: 1, Loss: 0.106734
# Epoch: 23, Iteration: 10, Loss: 0.186736
# Epoch: 23, Iteration: 19, Loss: 0.204130
# Epoch: 23, Iteration: 28, Loss: 0.096783
# Epoch: 23, Iteration: 37, Loss: 0.109971
# Epoch: 23, Iteration: 46, Loss: 0.147367
# Epoch: 23, Iteration: 55, Loss: 0.209568
# Epoch: 23, Iteration: 64, Loss: 0.445280
# Epoch: 23, Iteration: 73, Loss: 0.197716
# Epoch 23 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1405/1547 (91%)
#
# Epoch: 24, Iteration: 1, Loss: 0.461482
# Epoch: 24, Iteration: 10, Loss: 0.160599
# Epoch: 24, Iteration: 19, Loss: 0.072740
# Epoch: 24, Iteration: 28, Loss: 0.113122
# Epoch: 24, Iteration: 37, Loss: 0.086996
# Epoch: 24, Iteration: 46, Loss: 0.232621
# Epoch: 24, Iteration: 55, Loss: 0.356332
# Epoch: 24, Iteration: 64, Loss: 0.151449
# Epoch: 24, Iteration: 73, Loss: 0.233195
# Epoch 24 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1419/1547 (92%)
#
# Epoch: 25, Iteration: 1, Loss: 0.086734
# Epoch: 25, Iteration: 10, Loss: 0.195376
# Epoch: 25, Iteration: 19, Loss: 0.103839
# Epoch: 25, Iteration: 28, Loss: 0.212260
# Epoch: 25, Iteration: 37, Loss: 0.247983
# Epoch: 25, Iteration: 46, Loss: 0.209898
# Epoch: 25, Iteration: 55, Loss: 0.133661
# Epoch: 25, Iteration: 64, Loss: 0.137967
# Epoch: 25, Iteration: 73, Loss: 0.239487
# Epoch 25 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1430/1547 (92%)
#
# Epoch: 26, Iteration: 1, Loss: 0.140346
# Epoch: 26, Iteration: 10, Loss: 0.233277
# Epoch: 26, Iteration: 19, Loss: 0.185188
# Epoch: 26, Iteration: 28, Loss: 0.127778
# Epoch: 26, Iteration: 37, Loss: 0.073828
# Epoch: 26, Iteration: 46, Loss: 0.204171
# Epoch: 26, Iteration: 55, Loss: 0.140121
# Epoch: 26, Iteration: 64, Loss: 0.155888
# Epoch: 26, Iteration: 73, Loss: 0.087001
# Epoch 26 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1426/1547 (92%)
#
# Epoch: 27, Iteration: 1, Loss: 0.134613
# Epoch: 27, Iteration: 10, Loss: 0.120939
# Epoch: 27, Iteration: 19, Loss: 0.212542
# Epoch: 27, Iteration: 28, Loss: 0.229458
# Epoch: 27, Iteration: 37, Loss: 0.164986
# Epoch: 27, Iteration: 46, Loss: 0.118916
# Epoch: 27, Iteration: 55, Loss: 0.255010
# Epoch: 27, Iteration: 64, Loss: 0.132072
# Epoch: 27, Iteration: 73, Loss: 0.136819
# Epoch 27 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1410/1547 (91%)
#
# Epoch: 28, Iteration: 1, Loss: 0.143392
# Epoch: 28, Iteration: 10, Loss: 0.191140
# Epoch: 28, Iteration: 19, Loss: 0.281329
# Epoch: 28, Iteration: 28, Loss: 0.152542
# Epoch: 28, Iteration: 37, Loss: 0.060965
# Epoch: 28, Iteration: 46, Loss: 0.079571
# Epoch: 28, Iteration: 55, Loss: 0.240953
# Epoch: 28, Iteration: 64, Loss: 0.121795
# Epoch: 28, Iteration: 73, Loss: 0.093489
# Epoch 28 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1412/1547 (91%)
#
# Epoch: 29, Iteration: 1, Loss: 0.097898
# Epoch: 29, Iteration: 10, Loss: 0.139467
# Epoch: 29, Iteration: 19, Loss: 0.166118
# Epoch: 29, Iteration: 28, Loss: 0.227064
# Epoch: 29, Iteration: 37, Loss: 0.069313
# Epoch: 29, Iteration: 46, Loss: 0.124022
# Epoch: 29, Iteration: 55, Loss: 0.181858
# Epoch: 29, Iteration: 64, Loss: 0.184348
# Epoch: 29, Iteration: 73, Loss: 0.216387
# Epoch 29 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1420/1547 (92%)

# %%
# Save the trained model
model_save_path = '/content/histogram_model.pth'  # Path where you want to save the model
torch.save(model.state_dict(), model_save_path)
print(f'Model saved to {model_save_path}')
# Out:
# Model saved to /content/histogram_model.pth

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import torch.nn.functional as F  # For softmax

# Load the trained model
model = CNN_GSGD(input_size=input_size, num_classes=len(full_dataset.classes)).to(device)
model.load_state_dict(torch.load('/content/histogram_model.pth'))
model.eval()

# Get predictions and true labels for the test set
all_preds = []
all_labels = []
all_preds_prob = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        _, preds = torch.max(output, 1)  # Get predictions
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(target.cpu().numpy())
        all_preds_prob.extend(F.softmax(output, dim=1).cpu().numpy())  # Store probabilities

# Classification Report
print("Classification Report:")
print(classification_report(all_labels, all_preds))

# Confusion Matrix
cf_matrix = confusion_matrix(all_labels, all_preds)

# Visualizing Confusion Matrix
plt.figure(figsize=(8, 6))
plt.imshow(cf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
classes = list(full_dataset.classes)  # Assuming the class labels are present in the dataset
plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Add annotations to the confusion matrix
for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, str(cf_matrix[i, j]), ha='center', va='center', color='white')

plt.tight_layout()
plt.show()  # Display confusion matrix plot

# Print Confusion Matrix values
print("Confusion Matrix:")
print(cf_matrix)

# Determine if it's binary or multi-class
is_binary = len(classes) == 2  # If there are only two classes, it's binary classification

# Compute ROC Curve and AUC
lb = LabelBinarizer()
all_labels_bin = lb.fit_transform(all_labels)  # Convert labels to binary format

fpr = dict()
tpr = dict()
roc_auc = dict()

if is_binary:
    # For binary classification, we only need the positive class (class 1)
    fpr, tpr, _ = roc_curve(all_labels_bin, np.array(all_preds_prob)[:, 1])  # Get probabilities for class 1
    roc_auc = auc(fpr, tpr)
else:
    # For multi-class classification, compute ROC for each class
    for i in range(len(classes)):
        fpr[i], tpr[i], _ = roc_curve(all_labels_bin[:, i], np.array(all_preds_prob)[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

# Print ROC values
print("\nROC Values:")
if is_binary:
    print(f'Class 1: AUC = {roc_auc:.2f}')
else:
    for i in range(len(classes)):
        print(f'Class {classes[i]}: AUC = {roc_auc[i]:.2f}')

# Plot ROC curve
plt.figure(figsize=(8, 6))
if is_binary:
    plt.plot(fpr, tpr, label=f'Class 1 (AUC = {roc_auc:.2f})')
else:
    for i in range(len(classes)):
        plt.plot(fpr[i], tpr[i], label=f'Class {classes[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line (no discrimination)
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()  # Display ROC curve plot
# Out:
# <ipython-input-16-4ae14c43a8ba>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/histogram_model.pth'))
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       779
#            1       0.96      0.87      0.91       768
#
#     accuracy                           0.92      1547
#    macro avg       0.92      0.92      0.92      1547
# weighted avg       0.92      0.92      0.92      1547
# Confusion Matrix:
# [[753  26]
#  [101 667]]
#
# ROC Values:
# Class 1: AUC = 0.98

# %% [markdown]
# BAR GRAPHS

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import zipfile
import os

# Path to the ZIP file
zip_file_path = '/content/drive/My Drive/Heatmaps/bargraphs.zip'
extract_path = '/content/bargraphs'

# Verify if the ZIP file exists
if not os.path.exists(zip_file_path):
    raise FileNotFoundError(f"File not found: {zip_file_path}")

# Copy the ZIP file to Colab
# !cp "{zip_file_path}" /content

# Unzip the file
with zipfile.ZipFile('/content/bargraphs.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the path to the folder where your images are stored
data_path = '/content/bargraphs'  # Update this with the path to your images

# Step 1: Set up transformations (similar to MNIST preprocessing)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale if needed
    # transforms.Resize((28, 28)),  # Resize to 28x28 to match MNIST dimensions, adjust if needed
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to match MNIST-like preprocessing
])

# Step 2: Load the entire dataset using ImageFolder
full_dataset = datasets.ImageFolder(root=data_path, transform=transform)

# Step 3: Get input size dynamically from the first image in the dataset
sample_image, _ = full_dataset[0]  # Take the first image to determine the input shape
input_size = sample_image.shape  # This will be (C, H, W)

# Step 4: Split the dataset into training and testing sets
train_size = int(0.8 * len(full_dataset))  # 80% for training
test_size = len(full_dataset) - train_size  # Remaining 20% for testing
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

# Step 5: Create DataLoaders for both sets
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Split the train_dataset into training and validation datasets
train_size = int(0.8 * len(train_dataset))  # 80% for training
validation_size = len(train_dataset) - train_size  # Remaining 20% for validation
train_dataset, validation_dataset = random_split(train_dataset, [train_size, validation_size])

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)
validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN_GSGD(input_size=input_size, num_classes=len(full_dataset.classes)).to(device)

# model = EnhancedCNN_GSGD(num_classes=len(full_dataset.classes)).to(device)


# For Standard Guided SGD
# optimizer = GSGDOptimizer(model.parameters(), lr=0.01, method='sgd')

# For Guided SGD with Momentum
optimizer = GSGDOptimizer(model.parameters(), lr=0.01, method='momentum', momentum=0.9)

# For Guided Adam
# optimizer = GSGDOptimizer(model.parameters(), lr=0.001, method='adam', beta1=0.9, beta2=0.999)


# Define the loss function
loss_fn = nn.CrossEntropyLoss()

# %%
# Run training for each epoch, passing the dataset instead of DataLoader
for epoch in range(1, 30):
    train(model, device, train_loader.dataset, validation_loader.dataset, optimizer, epoch, loss_fn,
      verification_set_num=4, rho=10, log_interval=9)
    # train(model, device, train_loader.dataset, optimizer, epoch, loss_fn)  # Pass train_loader.dataset
    test(model, device, test_loader)
# Out:
# Epoch: 1, Iteration: 1, Loss: 0.703179
# Epoch: 1, Iteration: 10, Loss: 0.670600
# Epoch: 1, Iteration: 19, Loss: 0.687656
# Epoch: 1, Iteration: 28, Loss: 0.664929
# Epoch: 1, Iteration: 37, Loss: 0.615376
# Epoch: 1, Iteration: 46, Loss: 0.553707
# Epoch: 1, Iteration: 55, Loss: 0.550843
# Epoch: 1, Iteration: 64, Loss: 0.452500
# Epoch: 1, Iteration: 73, Loss: 0.549605
# Epoch 1 completed.
#
# Test set: Average loss: 0.0006, Accuracy: 1255/1547 (81%)
#
# Epoch: 2, Iteration: 1, Loss: 0.355676
# Epoch: 2, Iteration: 10, Loss: 0.404413
# Epoch: 2, Iteration: 19, Loss: 0.474486
# Epoch: 2, Iteration: 28, Loss: 0.454476
# Epoch: 2, Iteration: 37, Loss: 0.460515
# Epoch: 2, Iteration: 46, Loss: 0.430327
# Epoch: 2, Iteration: 55, Loss: 0.356041
# Epoch: 2, Iteration: 64, Loss: 0.430500
# Epoch: 2, Iteration: 73, Loss: 0.393257
# Epoch 2 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1286/1547 (83%)
#
# Epoch: 3, Iteration: 1, Loss: 0.388605
# Epoch: 3, Iteration: 10, Loss: 0.333925
# Epoch: 3, Iteration: 19, Loss: 0.293622
# Epoch: 3, Iteration: 28, Loss: 0.377955
# Epoch: 3, Iteration: 37, Loss: 0.463326
# Epoch: 3, Iteration: 46, Loss: 0.387658
# Epoch: 3, Iteration: 55, Loss: 0.353569
# Epoch: 3, Iteration: 64, Loss: 0.305164
# Epoch: 3, Iteration: 73, Loss: 0.290541
# Epoch 3 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1280/1547 (83%)
#
# Epoch: 4, Iteration: 1, Loss: 0.296382
# Epoch: 4, Iteration: 10, Loss: 0.321392
# Epoch: 4, Iteration: 19, Loss: 0.399303
# Epoch: 4, Iteration: 28, Loss: 0.340232
# Epoch: 4, Iteration: 37, Loss: 0.289279
# Epoch: 4, Iteration: 46, Loss: 0.373533
# Epoch: 4, Iteration: 55, Loss: 0.288264
# Epoch: 4, Iteration: 64, Loss: 0.238186
# Epoch: 4, Iteration: 73, Loss: 0.300957
# Epoch 4 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1305/1547 (84%)
#
# Epoch: 5, Iteration: 1, Loss: 0.267802
# Epoch: 5, Iteration: 10, Loss: 0.258695
# Epoch: 5, Iteration: 19, Loss: 0.444895
# Epoch: 5, Iteration: 28, Loss: 0.235515
# Epoch: 5, Iteration: 37, Loss: 0.256491
# Epoch: 5, Iteration: 46, Loss: 0.315346
# Epoch: 5, Iteration: 55, Loss: 0.232253
# Epoch: 5, Iteration: 64, Loss: 0.310094
# Epoch: 5, Iteration: 73, Loss: 0.260887
# Epoch 5 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1301/1547 (84%)
#
# Epoch: 6, Iteration: 1, Loss: 0.421796
# Epoch: 6, Iteration: 10, Loss: 0.322392
# Epoch: 6, Iteration: 19, Loss: 0.287796
# Epoch: 6, Iteration: 28, Loss: 0.321610
# Epoch: 6, Iteration: 37, Loss: 0.293704
# Epoch: 6, Iteration: 46, Loss: 0.300938
# Epoch: 6, Iteration: 55, Loss: 0.347234
# Epoch: 6, Iteration: 64, Loss: 0.375775
# Epoch: 6, Iteration: 73, Loss: 0.139078
# Epoch 6 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1341/1547 (87%)
#
# Epoch: 7, Iteration: 1, Loss: 0.262793
# Epoch: 7, Iteration: 10, Loss: 0.199313
# Epoch: 7, Iteration: 19, Loss: 0.238529
# Epoch: 7, Iteration: 28, Loss: 0.180446
# Epoch: 7, Iteration: 37, Loss: 0.212354
# Epoch: 7, Iteration: 46, Loss: 0.334187
# Epoch: 7, Iteration: 55, Loss: 0.414915
# Epoch: 7, Iteration: 64, Loss: 0.245743
# Epoch: 7, Iteration: 73, Loss: 0.340962
# Epoch 7 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1330/1547 (86%)
#
# Epoch: 8, Iteration: 1, Loss: 0.165167
# Epoch: 8, Iteration: 10, Loss: 0.167357
# Epoch: 8, Iteration: 19, Loss: 0.201509
# Epoch: 8, Iteration: 28, Loss: 0.229261
# Epoch: 8, Iteration: 37, Loss: 0.291246
# Epoch: 8, Iteration: 46, Loss: 0.200961
# Epoch: 8, Iteration: 55, Loss: 0.181431
# Epoch: 8, Iteration: 64, Loss: 0.163813
# Epoch: 8, Iteration: 73, Loss: 0.306250
# Epoch 8 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1283/1547 (83%)
#
# Epoch: 9, Iteration: 1, Loss: 0.352795
# Epoch: 9, Iteration: 10, Loss: 0.300430
# Epoch: 9, Iteration: 19, Loss: 0.244700
# Epoch: 9, Iteration: 28, Loss: 0.261176
# Epoch: 9, Iteration: 37, Loss: 0.251643
# Epoch: 9, Iteration: 46, Loss: 0.146657
# Epoch: 9, Iteration: 55, Loss: 0.220946
# Epoch: 9, Iteration: 64, Loss: 0.531368
# Epoch: 9, Iteration: 73, Loss: 0.174321
# Epoch 9 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1301/1547 (84%)
#
# Epoch: 10, Iteration: 1, Loss: 0.276082
# Epoch: 10, Iteration: 10, Loss: 0.326477
# Epoch: 10, Iteration: 19, Loss: 0.297221
# Epoch: 10, Iteration: 28, Loss: 0.091646
# Epoch: 10, Iteration: 37, Loss: 0.216654
# Epoch: 10, Iteration: 46, Loss: 0.171292
# Epoch: 10, Iteration: 55, Loss: 0.369304
# Epoch: 10, Iteration: 64, Loss: 0.234687
# Epoch: 10, Iteration: 73, Loss: 0.250666
# Epoch 10 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1362/1547 (88%)
#
# Epoch: 11, Iteration: 1, Loss: 0.134334
# Epoch: 11, Iteration: 10, Loss: 0.140523
# Epoch: 11, Iteration: 19, Loss: 0.317441
# Epoch: 11, Iteration: 28, Loss: 0.230278
# Epoch: 11, Iteration: 37, Loss: 0.253791
# Epoch: 11, Iteration: 46, Loss: 0.198141
# Epoch: 11, Iteration: 55, Loss: 0.195550
# Epoch: 11, Iteration: 64, Loss: 0.227326
# Epoch: 11, Iteration: 73, Loss: 0.281720
# Epoch 11 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1345/1547 (87%)
#
# Epoch: 12, Iteration: 1, Loss: 0.178826
# Epoch: 12, Iteration: 10, Loss: 0.181253
# Epoch: 12, Iteration: 19, Loss: 0.102628
# Epoch: 12, Iteration: 28, Loss: 0.198978
# Epoch: 12, Iteration: 37, Loss: 0.185290
# Epoch: 12, Iteration: 46, Loss: 0.223441
# Epoch: 12, Iteration: 55, Loss: 0.320519
# Epoch: 12, Iteration: 64, Loss: 0.190223
# Epoch: 12, Iteration: 73, Loss: 0.308872
# Epoch 12 completed.
#
# Test set: Average loss: 0.0007, Accuracy: 1245/1547 (80%)
#
# Epoch: 13, Iteration: 1, Loss: 0.303917
# Epoch: 13, Iteration: 10, Loss: 0.189984
# Epoch: 13, Iteration: 19, Loss: 0.130113
# Epoch: 13, Iteration: 28, Loss: 0.183414
# Epoch: 13, Iteration: 37, Loss: 0.155865
# Epoch: 13, Iteration: 46, Loss: 0.133897
# Epoch: 13, Iteration: 55, Loss: 0.220639
# Epoch: 13, Iteration: 64, Loss: 0.275696
# Epoch: 13, Iteration: 73, Loss: 0.277033
# Epoch 13 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1357/1547 (88%)
#
# Epoch: 14, Iteration: 1, Loss: 0.231445
# Epoch: 14, Iteration: 10, Loss: 0.159830
# Epoch: 14, Iteration: 19, Loss: 0.084641
# Epoch: 14, Iteration: 28, Loss: 0.207587
# Epoch: 14, Iteration: 37, Loss: 0.138609
# Epoch: 14, Iteration: 46, Loss: 0.177566
# Epoch: 14, Iteration: 55, Loss: 0.082544
# Epoch: 14, Iteration: 64, Loss: 0.238780
# Epoch: 14, Iteration: 73, Loss: 0.114451
# Epoch 14 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1348/1547 (87%)
#
# Epoch: 15, Iteration: 1, Loss: 0.083627
# Epoch: 15, Iteration: 10, Loss: 0.185119
# Epoch: 15, Iteration: 19, Loss: 0.303753
# Epoch: 15, Iteration: 28, Loss: 0.086719
# Epoch: 15, Iteration: 37, Loss: 0.159999
# Epoch: 15, Iteration: 46, Loss: 0.186881
# Epoch: 15, Iteration: 55, Loss: 0.155595
# Epoch: 15, Iteration: 64, Loss: 0.121826
# Epoch: 15, Iteration: 73, Loss: 0.403539
# Epoch 15 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1309/1547 (85%)
#
# Epoch: 16, Iteration: 1, Loss: 0.163745
# Epoch: 16, Iteration: 10, Loss: 0.135186
# Epoch: 16, Iteration: 19, Loss: 0.164653
# Epoch: 16, Iteration: 28, Loss: 0.096357
# Epoch: 16, Iteration: 37, Loss: 0.158750
# Epoch: 16, Iteration: 46, Loss: 0.090488
# Epoch: 16, Iteration: 55, Loss: 0.222979
# Epoch: 16, Iteration: 64, Loss: 0.142085
# Epoch: 16, Iteration: 73, Loss: 0.210596
# Epoch 16 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1351/1547 (87%)
#
# Epoch: 17, Iteration: 1, Loss: 0.116192
# Epoch: 17, Iteration: 10, Loss: 0.185730
# Epoch: 17, Iteration: 19, Loss: 0.108210
# Epoch: 17, Iteration: 28, Loss: 0.085728
# Epoch: 17, Iteration: 37, Loss: 0.138823
# Epoch: 17, Iteration: 46, Loss: 0.098546
# Epoch: 17, Iteration: 55, Loss: 0.184670
# Epoch: 17, Iteration: 64, Loss: 0.105657
# Epoch: 17, Iteration: 73, Loss: 0.045224
# Epoch 17 completed.
#
# Test set: Average loss: 0.0007, Accuracy: 1323/1547 (86%)
#
# Epoch: 18, Iteration: 1, Loss: 0.211532
# Epoch: 18, Iteration: 10, Loss: 0.228286
# Epoch: 18, Iteration: 19, Loss: 0.116103
# Epoch: 18, Iteration: 28, Loss: 0.120548
# Epoch: 18, Iteration: 37, Loss: 0.126982
# Epoch: 18, Iteration: 46, Loss: 0.088001
# Epoch: 18, Iteration: 55, Loss: 0.127101
# Epoch: 18, Iteration: 64, Loss: 0.131080
# Epoch: 18, Iteration: 73, Loss: 0.116278
# Epoch 18 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1355/1547 (88%)
#
# Epoch: 19, Iteration: 1, Loss: 0.099128
# Epoch: 19, Iteration: 10, Loss: 0.127577
# Epoch: 19, Iteration: 19, Loss: 0.091723
# Epoch: 19, Iteration: 28, Loss: 0.192610
# Epoch: 19, Iteration: 37, Loss: 0.207319
# Epoch: 19, Iteration: 46, Loss: 0.094313
# Epoch: 19, Iteration: 55, Loss: 0.089077
# Epoch: 19, Iteration: 64, Loss: 0.158222
# Epoch: 19, Iteration: 73, Loss: 0.136526
# Epoch 19 completed.
#
# Test set: Average loss: 0.0005, Accuracy: 1327/1547 (86%)
#
# Epoch: 20, Iteration: 1, Loss: 0.044050
# Epoch: 20, Iteration: 10, Loss: 0.084441
# Epoch: 20, Iteration: 19, Loss: 0.072118
# Epoch: 20, Iteration: 28, Loss: 0.126040
# Epoch: 20, Iteration: 37, Loss: 0.131216
# Epoch: 20, Iteration: 46, Loss: 0.025656
# Epoch: 20, Iteration: 55, Loss: 0.133602
# Epoch: 20, Iteration: 64, Loss: 0.021547
# Epoch: 20, Iteration: 73, Loss: 0.021246
# Epoch 20 completed.
#
# Test set: Average loss: 0.0006, Accuracy: 1356/1547 (88%)
#
# Epoch: 21, Iteration: 1, Loss: 0.050684
# Epoch: 21, Iteration: 10, Loss: 0.025154
# Epoch: 21, Iteration: 19, Loss: 0.039641
# Epoch: 21, Iteration: 28, Loss: 0.035328
# Epoch: 21, Iteration: 37, Loss: 0.137542
# Epoch: 21, Iteration: 46, Loss: 0.114331
# Epoch: 21, Iteration: 55, Loss: 0.080036
# Epoch: 21, Iteration: 64, Loss: 0.017264
# Epoch: 21, Iteration: 73, Loss: 0.056138
# Epoch 21 completed.
#
# Test set: Average loss: 0.0006, Accuracy: 1360/1547 (88%)
#
# Epoch: 22, Iteration: 1, Loss: 0.067238
# Epoch: 22, Iteration: 10, Loss: 0.046725
# Epoch: 22, Iteration: 19, Loss: 0.094630
# Epoch: 22, Iteration: 28, Loss: 0.016842
# Epoch: 22, Iteration: 37, Loss: 0.079108
# Epoch: 22, Iteration: 46, Loss: 0.052651
# Epoch: 22, Iteration: 55, Loss: 0.116172
# Epoch: 22, Iteration: 64, Loss: 0.060395
# Epoch: 22, Iteration: 73, Loss: 0.061354
# Epoch 22 completed.
#
# Test set: Average loss: 0.0006, Accuracy: 1335/1547 (86%)
#
# Epoch: 23, Iteration: 1, Loss: 0.018756
# Epoch: 23, Iteration: 10, Loss: 0.192690
# Epoch: 23, Iteration: 19, Loss: 0.173032
# Epoch: 23, Iteration: 28, Loss: 0.082369
# Epoch: 23, Iteration: 37, Loss: 0.053469
# Epoch: 23, Iteration: 46, Loss: 0.044772
# Epoch: 23, Iteration: 55, Loss: 0.022958
# Epoch: 23, Iteration: 64, Loss: 0.056884
# Epoch: 23, Iteration: 73, Loss: 0.009719
# Epoch 23 completed.
#
# Test set: Average loss: 0.0007, Accuracy: 1357/1547 (88%)
#
# Epoch: 24, Iteration: 1, Loss: 0.098988
# Epoch: 24, Iteration: 10, Loss: 0.139819
# Epoch: 24, Iteration: 19, Loss: 0.039144
# Epoch: 24, Iteration: 28, Loss: 0.027468
# Epoch: 24, Iteration: 37, Loss: 0.047119
# Epoch: 24, Iteration: 46, Loss: 0.086346
# Epoch: 24, Iteration: 55, Loss: 0.055024
# Epoch: 24, Iteration: 64, Loss: 0.027408
# Epoch: 24, Iteration: 73, Loss: 0.051612
# Epoch 24 completed.
#
# Test set: Average loss: 0.0009, Accuracy: 1333/1547 (86%)
#
# Epoch: 25, Iteration: 1, Loss: 0.057146
# Epoch: 25, Iteration: 10, Loss: 0.052360
# Epoch: 25, Iteration: 19, Loss: 0.039035
# Epoch: 25, Iteration: 28, Loss: 0.033228
# Epoch: 25, Iteration: 37, Loss: 0.017856
# Epoch: 25, Iteration: 46, Loss: 0.014774
# Epoch: 25, Iteration: 55, Loss: 0.022269
# Epoch: 25, Iteration: 64, Loss: 0.046027
# Epoch: 25, Iteration: 73, Loss: 0.044222
# Epoch 25 completed.
#
# Test set: Average loss: 0.0008, Accuracy: 1358/1547 (88%)
#
# Epoch: 26, Iteration: 1, Loss: 0.011385
# Epoch: 26, Iteration: 10, Loss: 0.024475
# Epoch: 26, Iteration: 19, Loss: 0.014800
# Epoch: 26, Iteration: 28, Loss: 0.069292
# Epoch: 26, Iteration: 37, Loss: 0.046530
# Epoch: 26, Iteration: 46, Loss: 0.109547
# Epoch: 26, Iteration: 55, Loss: 0.081504
# Epoch: 26, Iteration: 64, Loss: 0.045963
# Epoch: 26, Iteration: 73, Loss: 0.076469
# Epoch 26 completed.
#
# Test set: Average loss: 0.0009, Accuracy: 1350/1547 (87%)
#
# Epoch: 27, Iteration: 1, Loss: 0.038055
# Epoch: 27, Iteration: 10, Loss: 0.051665
# Epoch: 27, Iteration: 19, Loss: 0.025579
# Epoch: 27, Iteration: 28, Loss: 0.044774
# Epoch: 27, Iteration: 37, Loss: 0.059473
# Epoch: 27, Iteration: 46, Loss: 0.007265
# Epoch: 27, Iteration: 55, Loss: 0.031661
# Epoch: 27, Iteration: 64, Loss: 0.021402
# Epoch: 27, Iteration: 73, Loss: 0.020901
# Epoch 27 completed.
#
# Test set: Average loss: 0.0010, Accuracy: 1339/1547 (87%)
#
# Epoch: 28, Iteration: 1, Loss: 0.028044
# Epoch: 28, Iteration: 10, Loss: 0.010809
# Epoch: 28, Iteration: 19, Loss: 0.013170
# Epoch: 28, Iteration: 28, Loss: 0.063472
# Epoch: 28, Iteration: 37, Loss: 0.042795
# Epoch: 28, Iteration: 46, Loss: 0.105289
# Epoch: 28, Iteration: 55, Loss: 0.018507
# Epoch: 28, Iteration: 64, Loss: 0.008030
# Epoch: 28, Iteration: 73, Loss: 0.011045
# Epoch 28 completed.
#
# Test set: Average loss: 0.0009, Accuracy: 1341/1547 (87%)
#
# Epoch: 29, Iteration: 1, Loss: 0.022190
# Epoch: 29, Iteration: 10, Loss: 0.011355
# Epoch: 29, Iteration: 19, Loss: 0.016088
# Epoch: 29, Iteration: 28, Loss: 0.061878
# Epoch: 29, Iteration: 37, Loss: 0.040195
# Epoch: 29, Iteration: 46, Loss: 0.015231
# Epoch: 29, Iteration: 55, Loss: 0.011878
# Epoch: 29, Iteration: 64, Loss: 0.016041
# Epoch: 29, Iteration: 73, Loss: 0.003692
# Epoch 29 completed.
#
# Test set: Average loss: 0.0009, Accuracy: 1332/1547 (86%)

# %%
# Save the trained model
model_save_path = '/content/bargraph_model.pth'  # Path where you want to save the model
torch.save(model.state_dict(), model_save_path)
print(f'Model saved to {model_save_path}')
# Out:
# Model saved to /content/bargraph_model.pth

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import torch.nn.functional as F  # For softmax

# Load the trained model
model = CNN_GSGD(input_size=input_size, num_classes=len(full_dataset.classes)).to(device)
model.load_state_dict(torch.load('/content/bargraph_model.pth'))
model.eval()

# Get predictions and true labels for the test set
all_preds = []
all_labels = []
all_preds_prob = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        _, preds = torch.max(output, 1)  # Get predictions
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(target.cpu().numpy())
        all_preds_prob.extend(F.softmax(output, dim=1).cpu().numpy())  # Store probabilities

# Classification Report
print("Classification Report:")
print(classification_report(all_labels, all_preds))

# Confusion Matrix
cf_matrix = confusion_matrix(all_labels, all_preds)

# Visualizing Confusion Matrix
plt.figure(figsize=(8, 6))
plt.imshow(cf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
classes = list(full_dataset.classes)  # Assuming the class labels are present in the dataset
plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Add annotations to the confusion matrix
for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, str(cf_matrix[i, j]), ha='center', va='center', color='white')

plt.tight_layout()
plt.show()  # Display confusion matrix plot

# Print Confusion Matrix values
print("Confusion Matrix:")
print(cf_matrix)

# Determine if it's binary or multi-class
is_binary = len(classes) == 2  # If there are only two classes, it's binary classification

# Compute ROC Curve and AUC
lb = LabelBinarizer()
all_labels_bin = lb.fit_transform(all_labels)  # Convert labels to binary format

fpr = dict()
tpr = dict()
roc_auc = dict()

if is_binary:
    # For binary classification, we only need the positive class (class 1)
    fpr, tpr, _ = roc_curve(all_labels_bin, np.array(all_preds_prob)[:, 1])  # Get probabilities for class 1
    roc_auc = auc(fpr, tpr)
else:
    # For multi-class classification, compute ROC for each class
    for i in range(len(classes)):
        fpr[i], tpr[i], _ = roc_curve(all_labels_bin[:, i], np.array(all_preds_prob)[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

# Print ROC values
print("\nROC Values:")
if is_binary:
    print(f'Class 1: AUC = {roc_auc:.2f}')
else:
    for i in range(len(classes)):
        print(f'Class {classes[i]}: AUC = {roc_auc[i]:.2f}')

# Plot ROC curve
plt.figure(figsize=(8, 6))
if is_binary:
    plt.plot(fpr, tpr, label=f'Class 1 (AUC = {roc_auc:.2f})')
else:
    for i in range(len(classes)):
        plt.plot(fpr[i], tpr[i], label=f'Class {classes[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line (no discrimination)
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()  # Display ROC curve plot
# Out:
# <ipython-input-22-6e1f1e8f9b0b>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/bargraph_model.pth'))
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       780
#            1       0.83      0.90      0.86       767
#
#     accuracy                           0.86      1547
#    macro avg       0.86      0.86      0.86      1547
# weighted avg       0.86      0.86      0.86      1547
# Confusion Matrix:
# [[644 136]
#  [ 79 688]]
#
# ROC Values:
# Class 1: AUC = 0.94

# %% [markdown]
# HEATMAPS

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import zipfile
import os

# Path to the ZIP file
zip_file_path = '/content/drive/My Drive/Heatmaps/heatmaps.zip'
extract_path = '/content/heatmaps'

# Verify if the ZIP file exists
if not os.path.exists(zip_file_path):
    raise FileNotFoundError(f"File not found: {zip_file_path}")

# Copy the ZIP file to Colab
# !cp "{zip_file_path}" /content

# Unzip the file
with zipfile.ZipFile('/content/heatmaps.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# Mounted at /content/drive

# %%
# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the path to the folder where your images are stored
data_path = '/content/heatmaps'  # Update this with the path to your images

# Step 1: Set up transformations (similar to MNIST preprocessing)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale if needed
    # transforms.Resize((28, 28)),  # Resize to 28x28 to match MNIST dimensions, adjust if needed
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to match MNIST-like preprocessing
])

# Step 2: Load the entire dataset using ImageFolder
full_dataset = datasets.ImageFolder(root=data_path, transform=transform)

# Step 3: Get input size dynamically from the first image in the dataset
sample_image, _ = full_dataset[0]  # Take the first image to determine the input shape
input_size = sample_image.shape  # This will be (C, H, W)

# Step 4: Split the dataset into training and testing sets
train_size = int(0.8 * len(full_dataset))  # 80% for training
test_size = len(full_dataset) - train_size  # Remaining 20% for testing
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

# Step 5: Create DataLoaders for both sets
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Split the train_dataset into training and validation datasets
train_size = int(0.8 * len(train_dataset))  # 80% for training
validation_size = len(train_dataset) - train_size  # Remaining 20% for validation
train_dataset, validation_dataset = random_split(train_dataset, [train_size, validation_size])

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)
validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN_GSGD(input_size=input_size, num_classes=len(full_dataset.classes)).to(device)

# model = EnhancedCNN_GSGD(num_classes=len(full_dataset.classes)).to(device)
# For Standard Guided SGD
# optimizer = GSGDOptimizer(model.parameters(), lr=0.01, method='sgd')

# For Guided SGD with Momentum
optimizer = GSGDOptimizer(model.parameters(), lr=0.01, method='momentum', momentum=0.9)

# For Guided Adam
# optimizer = GSGDOptimizer(model.parameters(), lr=0.001, method='adam', beta1=0.9, beta2=0.999)

# %%
# Define the loss function
loss_fn = nn.CrossEntropyLoss()

# Run training for each epoch, passing the dataset instead of DataLoader
for epoch in range(1, 30):
    train(model, device, train_loader.dataset, validation_loader.dataset, optimizer, epoch, loss_fn,
      verification_set_num=4, rho=10, log_interval=2)
    # train(model, device, train_loader.dataset, optimizer, epoch, loss_fn)  # Pass train_loader.dataset
    test(model, device, test_loader)
# Out:
# Epoch: 1, Iteration: 1, Loss: 0.692540
# Epoch: 1, Iteration: 3, Loss: 0.691020
# Epoch: 1, Iteration: 5, Loss: 0.675767
# Epoch: 1, Iteration: 7, Loss: 0.656056
# Epoch: 1, Iteration: 9, Loss: 0.638021
# Epoch: 1, Iteration: 11, Loss: 0.581345
# Epoch: 1, Iteration: 13, Loss: 0.494787
# Epoch: 1, Iteration: 15, Loss: 0.483144
# Epoch: 1, Iteration: 17, Loss: 0.610835
# Epoch: 1, Iteration: 19, Loss: 0.376842
# Epoch: 1, Iteration: 21, Loss: 0.690455
# Epoch: 1, Iteration: 23, Loss: 0.414035
# Epoch: 1, Iteration: 25, Loss: 0.479531
# Epoch: 1, Iteration: 27, Loss: 0.573504
# Epoch: 1, Iteration: 29, Loss: 0.434290
# Epoch: 1, Iteration: 31, Loss: 0.445731
# Epoch: 1, Iteration: 33, Loss: 0.472264
# Epoch: 1, Iteration: 35, Loss: 0.442028
# Epoch: 1, Iteration: 37, Loss: 0.468631
# Epoch: 1, Iteration: 39, Loss: 0.344348
# Epoch: 1, Iteration: 41, Loss: 0.386725
# Epoch: 1, Iteration: 43, Loss: 0.361739
# Epoch: 1, Iteration: 45, Loss: 0.541337
# Epoch: 1, Iteration: 47, Loss: 0.408847
# Epoch: 1, Iteration: 49, Loss: 0.412136
# Epoch: 1, Iteration: 51, Loss: 0.416579
# Epoch: 1, Iteration: 53, Loss: 0.339838
# Epoch: 1, Iteration: 55, Loss: 0.388564
# Epoch: 1, Iteration: 57, Loss: 0.411858
# Epoch: 1, Iteration: 59, Loss: 0.290697
# Epoch: 1, Iteration: 61, Loss: 0.284162
# Epoch: 1, Iteration: 63, Loss: 0.353339
# Epoch: 1, Iteration: 65, Loss: 0.400812
# Epoch: 1, Iteration: 67, Loss: 0.338960
# Epoch: 1, Iteration: 69, Loss: 0.301279
# Epoch: 1, Iteration: 71, Loss: 0.370777
# Epoch: 1, Iteration: 73, Loss: 0.300781
# Epoch 1 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1328/1547 (86%)
#
# Epoch: 2, Iteration: 1, Loss: 0.346551
# Epoch: 2, Iteration: 3, Loss: 0.351125
# Epoch: 2, Iteration: 5, Loss: 0.367827
# Epoch: 2, Iteration: 7, Loss: 0.317319
# Epoch: 2, Iteration: 9, Loss: 0.354107
# Epoch: 2, Iteration: 11, Loss: 0.269835
# Epoch: 2, Iteration: 13, Loss: 0.396663
# Epoch: 2, Iteration: 15, Loss: 0.331616
# Epoch: 2, Iteration: 17, Loss: 0.308132
# Epoch: 2, Iteration: 19, Loss: 0.472514
# Epoch: 2, Iteration: 21, Loss: 0.275027
# Epoch: 2, Iteration: 23, Loss: 0.370947
# Epoch: 2, Iteration: 25, Loss: 0.346916
# Epoch: 2, Iteration: 27, Loss: 0.332850
# Epoch: 2, Iteration: 29, Loss: 0.299438
# Epoch: 2, Iteration: 31, Loss: 0.210993
# Epoch: 2, Iteration: 33, Loss: 0.353967
# Epoch: 2, Iteration: 35, Loss: 0.239392
# Epoch: 2, Iteration: 37, Loss: 0.349128
# Epoch: 2, Iteration: 39, Loss: 0.202589
# Epoch: 2, Iteration: 41, Loss: 0.339035
# Epoch: 2, Iteration: 43, Loss: 0.273276
# Epoch: 2, Iteration: 45, Loss: 0.231957
# Epoch: 2, Iteration: 47, Loss: 0.215479
# Epoch: 2, Iteration: 49, Loss: 0.305353
# Epoch: 2, Iteration: 51, Loss: 0.395768
# Epoch: 2, Iteration: 53, Loss: 0.411149
# Epoch: 2, Iteration: 55, Loss: 0.346071
# Epoch: 2, Iteration: 57, Loss: 0.310503
# Epoch: 2, Iteration: 59, Loss: 0.226633
# Epoch: 2, Iteration: 61, Loss: 0.209114
# Epoch: 2, Iteration: 63, Loss: 0.224731
# Epoch: 2, Iteration: 65, Loss: 0.167569
# Epoch: 2, Iteration: 67, Loss: 0.407536
# Epoch: 2, Iteration: 69, Loss: 0.435591
# Epoch: 2, Iteration: 71, Loss: 0.312637
# Epoch: 2, Iteration: 73, Loss: 0.275137
# Epoch 2 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1367/1547 (88%)
#
# Epoch: 3, Iteration: 1, Loss: 0.290756
# Epoch: 3, Iteration: 3, Loss: 0.245749
# Epoch: 3, Iteration: 5, Loss: 0.267243
# Epoch: 3, Iteration: 7, Loss: 0.229894
# Epoch: 3, Iteration: 9, Loss: 0.178018
# Epoch: 3, Iteration: 11, Loss: 0.232718
# Epoch: 3, Iteration: 13, Loss: 0.201567
# Epoch: 3, Iteration: 15, Loss: 0.237171
# Epoch: 3, Iteration: 17, Loss: 0.267556
# Epoch: 3, Iteration: 19, Loss: 0.240060
# Epoch: 3, Iteration: 21, Loss: 0.257742
# Epoch: 3, Iteration: 23, Loss: 0.246529
# Epoch: 3, Iteration: 25, Loss: 0.304417
# Epoch: 3, Iteration: 27, Loss: 0.259929
# Epoch: 3, Iteration: 29, Loss: 0.345883
# Epoch: 3, Iteration: 31, Loss: 0.335657
# Epoch: 3, Iteration: 33, Loss: 0.248870
# Epoch: 3, Iteration: 35, Loss: 0.307609
# Epoch: 3, Iteration: 37, Loss: 0.275688
# Epoch: 3, Iteration: 39, Loss: 0.169357
# Epoch: 3, Iteration: 41, Loss: 0.141348
# Epoch: 3, Iteration: 43, Loss: 0.230342
# Epoch: 3, Iteration: 45, Loss: 0.433612
# Epoch: 3, Iteration: 47, Loss: 0.266117
# Epoch: 3, Iteration: 49, Loss: 0.270354
# Epoch: 3, Iteration: 51, Loss: 0.242733
# Epoch: 3, Iteration: 53, Loss: 0.325064
# Epoch: 3, Iteration: 55, Loss: 0.264289
# Epoch: 3, Iteration: 57, Loss: 0.250142
# Epoch: 3, Iteration: 59, Loss: 0.287379
# Epoch: 3, Iteration: 61, Loss: 0.180515
# Epoch: 3, Iteration: 63, Loss: 0.195572
# Epoch: 3, Iteration: 65, Loss: 0.337718
# Epoch: 3, Iteration: 67, Loss: 0.233095
# Epoch: 3, Iteration: 69, Loss: 0.268428
# Epoch: 3, Iteration: 71, Loss: 0.208494
# Epoch: 3, Iteration: 73, Loss: 0.167730
# Epoch 3 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1399/1547 (90%)
#
# Epoch: 4, Iteration: 1, Loss: 0.280872
# Epoch: 4, Iteration: 3, Loss: 0.287757
# Epoch: 4, Iteration: 5, Loss: 0.198819
# Epoch: 4, Iteration: 7, Loss: 0.307626
# Epoch: 4, Iteration: 9, Loss: 0.235966
# Epoch: 4, Iteration: 11, Loss: 0.261111
# Epoch: 4, Iteration: 13, Loss: 0.261728
# Epoch: 4, Iteration: 15, Loss: 0.227542
# Epoch: 4, Iteration: 17, Loss: 0.168607
# Epoch: 4, Iteration: 19, Loss: 0.299430
# Epoch: 4, Iteration: 21, Loss: 0.264309
# Epoch: 4, Iteration: 23, Loss: 0.279476
# Epoch: 4, Iteration: 25, Loss: 0.270565
# Epoch: 4, Iteration: 27, Loss: 0.264356
# Epoch: 4, Iteration: 29, Loss: 0.282889
# Epoch: 4, Iteration: 31, Loss: 0.230478
# Epoch: 4, Iteration: 33, Loss: 0.351898
# Epoch: 4, Iteration: 35, Loss: 0.271346
# Epoch: 4, Iteration: 37, Loss: 0.288580
# Epoch: 4, Iteration: 39, Loss: 0.242571
# Epoch: 4, Iteration: 41, Loss: 0.258874
# Epoch: 4, Iteration: 43, Loss: 0.327462
# Epoch: 4, Iteration: 45, Loss: 0.243802
# Epoch: 4, Iteration: 47, Loss: 0.267809
# Epoch: 4, Iteration: 49, Loss: 0.252019
# Epoch: 4, Iteration: 51, Loss: 0.263224
# Epoch: 4, Iteration: 53, Loss: 0.295459
# Epoch: 4, Iteration: 55, Loss: 0.274558
# Epoch: 4, Iteration: 57, Loss: 0.185429
# Epoch: 4, Iteration: 59, Loss: 0.117621
# Epoch: 4, Iteration: 61, Loss: 0.141656
# Epoch: 4, Iteration: 63, Loss: 0.254352
# Epoch: 4, Iteration: 65, Loss: 0.365985
# Epoch: 4, Iteration: 67, Loss: 0.239725
# Epoch: 4, Iteration: 69, Loss: 0.221215
# Epoch: 4, Iteration: 71, Loss: 0.183575
# Epoch: 4, Iteration: 73, Loss: 0.142926
# Epoch 4 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1401/1547 (91%)
#
# Epoch: 5, Iteration: 1, Loss: 0.306412
# Epoch: 5, Iteration: 3, Loss: 0.167159
# Epoch: 5, Iteration: 5, Loss: 0.297305
# Epoch: 5, Iteration: 7, Loss: 0.437442
# Epoch: 5, Iteration: 9, Loss: 0.175317
# Epoch: 5, Iteration: 11, Loss: 0.169702
# Epoch: 5, Iteration: 13, Loss: 0.231307
# Epoch: 5, Iteration: 15, Loss: 0.206321
# Epoch: 5, Iteration: 17, Loss: 0.231842
# Epoch: 5, Iteration: 19, Loss: 0.324281
# Epoch: 5, Iteration: 21, Loss: 0.287524
# Epoch: 5, Iteration: 23, Loss: 0.153901
# Epoch: 5, Iteration: 25, Loss: 0.189040
# Epoch: 5, Iteration: 27, Loss: 0.326654
# Epoch: 5, Iteration: 29, Loss: 0.186456
# Epoch: 5, Iteration: 31, Loss: 0.285449
# Epoch: 5, Iteration: 33, Loss: 0.302118
# Epoch: 5, Iteration: 35, Loss: 0.203716
# Epoch: 5, Iteration: 37, Loss: 0.205118
# Epoch: 5, Iteration: 39, Loss: 0.178276
# Epoch: 5, Iteration: 41, Loss: 0.325746
# Epoch: 5, Iteration: 43, Loss: 0.155920
# Epoch: 5, Iteration: 45, Loss: 0.152915
# Epoch: 5, Iteration: 47, Loss: 0.150534
# Epoch: 5, Iteration: 49, Loss: 0.249213
# Epoch: 5, Iteration: 51, Loss: 0.296457
# Epoch: 5, Iteration: 53, Loss: 0.236314
# Epoch: 5, Iteration: 55, Loss: 0.161133
# Epoch: 5, Iteration: 57, Loss: 0.124327
# Epoch: 5, Iteration: 59, Loss: 0.399003
# Epoch: 5, Iteration: 61, Loss: 0.524318
# Epoch: 5, Iteration: 63, Loss: 0.232535
# Epoch: 5, Iteration: 65, Loss: 0.329028
# Epoch: 5, Iteration: 67, Loss: 0.172947
# Epoch: 5, Iteration: 69, Loss: 0.369111
# Epoch: 5, Iteration: 71, Loss: 0.307460
# Epoch: 5, Iteration: 73, Loss: 0.317225
# Epoch 5 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1402/1547 (91%)
#
# Epoch: 6, Iteration: 1, Loss: 0.220673
# Epoch: 6, Iteration: 3, Loss: 0.244289
# Epoch: 6, Iteration: 5, Loss: 0.290646
# Epoch: 6, Iteration: 7, Loss: 0.337013
# Epoch: 6, Iteration: 9, Loss: 0.116894
# Epoch: 6, Iteration: 11, Loss: 0.271796
# Epoch: 6, Iteration: 13, Loss: 0.313330
# Epoch: 6, Iteration: 15, Loss: 0.266808
# Epoch: 6, Iteration: 17, Loss: 0.228497
# Epoch: 6, Iteration: 19, Loss: 0.192139
# Epoch: 6, Iteration: 21, Loss: 0.184912
# Epoch: 6, Iteration: 23, Loss: 0.181890
# Epoch: 6, Iteration: 25, Loss: 0.112669
# Epoch: 6, Iteration: 27, Loss: 0.207176
# Epoch: 6, Iteration: 29, Loss: 0.338409
# Epoch: 6, Iteration: 31, Loss: 0.199713
# Epoch: 6, Iteration: 33, Loss: 0.383109
# Epoch: 6, Iteration: 35, Loss: 0.112318
# Epoch: 6, Iteration: 37, Loss: 0.170822
# Epoch: 6, Iteration: 39, Loss: 0.335343
# Epoch: 6, Iteration: 41, Loss: 0.204101
# Epoch: 6, Iteration: 43, Loss: 0.225094
# Epoch: 6, Iteration: 45, Loss: 0.191266
# Epoch: 6, Iteration: 47, Loss: 0.121096
# Epoch: 6, Iteration: 49, Loss: 0.238663
# Epoch: 6, Iteration: 51, Loss: 0.289659
# Epoch: 6, Iteration: 53, Loss: 0.192038
# Epoch: 6, Iteration: 55, Loss: 0.150734
# Epoch: 6, Iteration: 57, Loss: 0.164052
# Epoch: 6, Iteration: 59, Loss: 0.401708
# Epoch: 6, Iteration: 61, Loss: 0.394298
# Epoch: 6, Iteration: 63, Loss: 0.226572
# Epoch: 6, Iteration: 65, Loss: 0.249062
# Epoch: 6, Iteration: 67, Loss: 0.174977
# Epoch: 6, Iteration: 69, Loss: 0.402695
# Epoch: 6, Iteration: 71, Loss: 0.267957
# Epoch: 6, Iteration: 73, Loss: 0.212595
# Epoch 6 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1400/1547 (90%)
#
# Epoch: 7, Iteration: 1, Loss: 0.186872
# Epoch: 7, Iteration: 3, Loss: 0.155762
# Epoch: 7, Iteration: 5, Loss: 0.257668
# Epoch: 7, Iteration: 7, Loss: 0.148681
# Epoch: 7, Iteration: 9, Loss: 0.103689
# Epoch: 7, Iteration: 11, Loss: 0.138800
# Epoch: 7, Iteration: 13, Loss: 0.270470
# Epoch: 7, Iteration: 15, Loss: 0.201783
# Epoch: 7, Iteration: 17, Loss: 0.307912
# Epoch: 7, Iteration: 19, Loss: 0.405321
# Epoch: 7, Iteration: 21, Loss: 0.248289
# Epoch: 7, Iteration: 23, Loss: 0.246769
# Epoch: 7, Iteration: 25, Loss: 0.188802
# Epoch: 7, Iteration: 27, Loss: 0.179672
# Epoch: 7, Iteration: 29, Loss: 0.190073
# Epoch: 7, Iteration: 31, Loss: 0.150344
# Epoch: 7, Iteration: 33, Loss: 0.334977
# Epoch: 7, Iteration: 35, Loss: 0.091526
# Epoch: 7, Iteration: 37, Loss: 0.226870
# Epoch: 7, Iteration: 39, Loss: 0.208294
# Epoch: 7, Iteration: 41, Loss: 0.299114
# Epoch: 7, Iteration: 43, Loss: 0.360051
# Epoch: 7, Iteration: 45, Loss: 0.253349
# Epoch: 7, Iteration: 47, Loss: 0.255029
# Epoch: 7, Iteration: 49, Loss: 0.372698
# Epoch: 7, Iteration: 51, Loss: 0.234944
# Epoch: 7, Iteration: 53, Loss: 0.285645
# Epoch: 7, Iteration: 55, Loss: 0.112882
# Epoch: 7, Iteration: 57, Loss: 0.130286
# Epoch: 7, Iteration: 59, Loss: 0.251254
# Epoch: 7, Iteration: 61, Loss: 0.212718
# Epoch: 7, Iteration: 63, Loss: 0.177941
# Epoch: 7, Iteration: 65, Loss: 0.331292
# Epoch: 7, Iteration: 67, Loss: 0.236214
# Epoch: 7, Iteration: 69, Loss: 0.266266
# Epoch: 7, Iteration: 71, Loss: 0.209465
# Epoch: 7, Iteration: 73, Loss: 0.121117
# Epoch 7 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1380/1547 (89%)
#
# Epoch: 8, Iteration: 1, Loss: 0.180626
# Epoch: 8, Iteration: 3, Loss: 0.307155
# Epoch: 8, Iteration: 5, Loss: 0.253191
# Epoch: 8, Iteration: 7, Loss: 0.226403
# Epoch: 8, Iteration: 9, Loss: 0.237521
# Epoch: 8, Iteration: 11, Loss: 0.208527
# Epoch: 8, Iteration: 13, Loss: 0.472586
# Epoch: 8, Iteration: 15, Loss: 0.275539
# Epoch: 8, Iteration: 17, Loss: 0.204892
# Epoch: 8, Iteration: 19, Loss: 0.312779
# Epoch: 8, Iteration: 21, Loss: 0.183457
# Epoch: 8, Iteration: 23, Loss: 0.186024
# Epoch: 8, Iteration: 25, Loss: 0.287480
# Epoch: 8, Iteration: 27, Loss: 0.228756
# Epoch: 8, Iteration: 29, Loss: 0.179488
# Epoch: 8, Iteration: 31, Loss: 0.203031
# Epoch: 8, Iteration: 33, Loss: 0.092180
# Epoch: 8, Iteration: 35, Loss: 0.128597
# Epoch: 8, Iteration: 37, Loss: 0.146972
# Epoch: 8, Iteration: 39, Loss: 0.178518
# Epoch: 8, Iteration: 41, Loss: 0.239202
# Epoch: 8, Iteration: 43, Loss: 0.085984
# Epoch: 8, Iteration: 45, Loss: 0.137200
# Epoch: 8, Iteration: 47, Loss: 0.125852
# Epoch: 8, Iteration: 49, Loss: 0.212318
# Epoch: 8, Iteration: 51, Loss: 0.205307
# Epoch: 8, Iteration: 53, Loss: 0.170939
# Epoch: 8, Iteration: 55, Loss: 0.165120
# Epoch: 8, Iteration: 57, Loss: 0.159404
# Epoch: 8, Iteration: 59, Loss: 0.149216
# Epoch: 8, Iteration: 61, Loss: 0.186083
# Epoch: 8, Iteration: 63, Loss: 0.234697
# Epoch: 8, Iteration: 65, Loss: 0.179553
# Epoch: 8, Iteration: 67, Loss: 0.194879
# Epoch: 8, Iteration: 69, Loss: 0.181516
# Epoch: 8, Iteration: 71, Loss: 0.183370
# Epoch: 8, Iteration: 73, Loss: 0.240003
# Epoch 8 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1381/1547 (89%)
#
# Epoch: 9, Iteration: 1, Loss: 0.275129
# Epoch: 9, Iteration: 3, Loss: 0.213673
# Epoch: 9, Iteration: 5, Loss: 0.411134
# Epoch: 9, Iteration: 7, Loss: 0.207704
# Epoch: 9, Iteration: 9, Loss: 0.165310
# Epoch: 9, Iteration: 11, Loss: 0.197828
# Epoch: 9, Iteration: 13, Loss: 0.157005
# Epoch: 9, Iteration: 15, Loss: 0.208867
# Epoch: 9, Iteration: 17, Loss: 0.291446
# Epoch: 9, Iteration: 19, Loss: 0.270640
# Epoch: 9, Iteration: 21, Loss: 0.238254
# Epoch: 9, Iteration: 23, Loss: 0.443500
# Epoch: 9, Iteration: 25, Loss: 0.177670
# Epoch: 9, Iteration: 27, Loss: 0.325020
# Epoch: 9, Iteration: 29, Loss: 0.286621
# Epoch: 9, Iteration: 31, Loss: 0.194072
# Epoch: 9, Iteration: 33, Loss: 0.145658
# Epoch: 9, Iteration: 35, Loss: 0.354059
# Epoch: 9, Iteration: 37, Loss: 0.194516
# Epoch: 9, Iteration: 39, Loss: 0.163215
# Epoch: 9, Iteration: 41, Loss: 0.104134
# Epoch: 9, Iteration: 43, Loss: 0.215985
# Epoch: 9, Iteration: 45, Loss: 0.115626
# Epoch: 9, Iteration: 47, Loss: 0.198307
# Epoch: 9, Iteration: 49, Loss: 0.131530
# Epoch: 9, Iteration: 51, Loss: 0.165819
# Epoch: 9, Iteration: 53, Loss: 0.214020
# Epoch: 9, Iteration: 55, Loss: 0.193264
# Epoch: 9, Iteration: 57, Loss: 0.262501
# Epoch: 9, Iteration: 59, Loss: 0.118608
# Epoch: 9, Iteration: 61, Loss: 0.251106
# Epoch: 9, Iteration: 63, Loss: 0.311171
# Epoch: 9, Iteration: 65, Loss: 0.119540
# Epoch: 9, Iteration: 67, Loss: 0.142917
# Epoch: 9, Iteration: 69, Loss: 0.205043
# Epoch: 9, Iteration: 71, Loss: 0.206710
# Epoch: 9, Iteration: 73, Loss: 0.120287
# Epoch 9 completed.
#
# Test set: Average loss: 0.0004, Accuracy: 1371/1547 (89%)
#
# Epoch: 10, Iteration: 1, Loss: 0.284345
# Epoch: 10, Iteration: 3, Loss: 0.287247
# Epoch: 10, Iteration: 5, Loss: 0.124691
# Epoch: 10, Iteration: 7, Loss: 0.197834
# Epoch: 10, Iteration: 9, Loss: 0.167180
# Epoch: 10, Iteration: 11, Loss: 0.187990
# Epoch: 10, Iteration: 13, Loss: 0.287298
# Epoch: 10, Iteration: 15, Loss: 0.149624
# Epoch: 10, Iteration: 17, Loss: 0.203139
# Epoch: 10, Iteration: 19, Loss: 0.171595
# Epoch: 10, Iteration: 21, Loss: 0.123763
# Epoch: 10, Iteration: 23, Loss: 0.074701
# Epoch: 10, Iteration: 25, Loss: 0.283926
# Epoch: 10, Iteration: 27, Loss: 0.101318
# Epoch: 10, Iteration: 29, Loss: 0.321848
# Epoch: 10, Iteration: 31, Loss: 0.254010
# Epoch: 10, Iteration: 33, Loss: 0.132194
# Epoch: 10, Iteration: 35, Loss: 0.094475
# Epoch: 10, Iteration: 37, Loss: 0.223496
# Epoch: 10, Iteration: 39, Loss: 0.141715
# Epoch: 10, Iteration: 41, Loss: 0.247984
# Epoch: 10, Iteration: 43, Loss: 0.151978
# Epoch: 10, Iteration: 45, Loss: 0.121546
# Epoch: 10, Iteration: 47, Loss: 0.079275
# Epoch: 10, Iteration: 49, Loss: 0.167970
# Epoch: 10, Iteration: 51, Loss: 0.174912
# Epoch: 10, Iteration: 53, Loss: 0.161390
# Epoch: 10, Iteration: 55, Loss: 0.224340
# Epoch: 10, Iteration: 57, Loss: 0.139676
# Epoch: 10, Iteration: 59, Loss: 0.179507
# Epoch: 10, Iteration: 61, Loss: 0.119134
# Epoch: 10, Iteration: 63, Loss: 0.367139
# Epoch: 10, Iteration: 65, Loss: 0.131885
# Epoch: 10, Iteration: 67, Loss: 0.236580
# Epoch: 10, Iteration: 69, Loss: 0.217394
# Epoch: 10, Iteration: 71, Loss: 0.090944
# Epoch: 10, Iteration: 73, Loss: 0.146833
# Epoch 10 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1405/1547 (91%)
#
# Epoch: 11, Iteration: 1, Loss: 0.206300
# Epoch: 11, Iteration: 3, Loss: 0.192227
# Epoch: 11, Iteration: 5, Loss: 0.167911
# Epoch: 11, Iteration: 7, Loss: 0.134628
# Epoch: 11, Iteration: 9, Loss: 0.141705
# Epoch: 11, Iteration: 11, Loss: 0.166112
# Epoch: 11, Iteration: 13, Loss: 0.112122
# Epoch: 11, Iteration: 15, Loss: 0.221563
# Epoch: 11, Iteration: 17, Loss: 0.117959
# Epoch: 11, Iteration: 19, Loss: 0.133692
# Epoch: 11, Iteration: 21, Loss: 0.082993
# Epoch: 11, Iteration: 23, Loss: 0.262733
# Epoch: 11, Iteration: 25, Loss: 0.254847
# Epoch: 11, Iteration: 27, Loss: 0.174458
# Epoch: 11, Iteration: 29, Loss: 0.118966
# Epoch: 11, Iteration: 31, Loss: 0.226389
# Epoch: 11, Iteration: 33, Loss: 0.150147
# Epoch: 11, Iteration: 35, Loss: 0.143385
# Epoch: 11, Iteration: 37, Loss: 0.172575
# Epoch: 11, Iteration: 39, Loss: 0.126073
# Epoch: 11, Iteration: 41, Loss: 0.175200
# Epoch: 11, Iteration: 43, Loss: 0.110738
# Epoch: 11, Iteration: 45, Loss: 0.247606
# Epoch: 11, Iteration: 47, Loss: 0.139183
# Epoch: 11, Iteration: 49, Loss: 0.147674
# Epoch: 11, Iteration: 51, Loss: 0.092161
# Epoch: 11, Iteration: 53, Loss: 0.099043
# Epoch: 11, Iteration: 55, Loss: 0.082317
# Epoch: 11, Iteration: 57, Loss: 0.194244
# Epoch: 11, Iteration: 59, Loss: 0.193822
# Epoch: 11, Iteration: 61, Loss: 0.120519
# Epoch: 11, Iteration: 63, Loss: 0.123167
# Epoch: 11, Iteration: 65, Loss: 0.215113
# Epoch: 11, Iteration: 67, Loss: 0.400369
# Epoch: 11, Iteration: 69, Loss: 0.204238
# Epoch: 11, Iteration: 71, Loss: 0.118809
# Epoch: 11, Iteration: 73, Loss: 0.234283
# Epoch 11 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1435/1547 (93%)
#
# Epoch: 12, Iteration: 1, Loss: 0.142321
# Epoch: 12, Iteration: 3, Loss: 0.095293
# Epoch: 12, Iteration: 5, Loss: 0.106483
# Epoch: 12, Iteration: 7, Loss: 0.224304
# Epoch: 12, Iteration: 9, Loss: 0.266859
# Epoch: 12, Iteration: 11, Loss: 0.079625
# Epoch: 12, Iteration: 13, Loss: 0.185892
# Epoch: 12, Iteration: 15, Loss: 0.093172
# Epoch: 12, Iteration: 17, Loss: 0.146600
# Epoch: 12, Iteration: 19, Loss: 0.177374
# Epoch: 12, Iteration: 21, Loss: 0.180212
# Epoch: 12, Iteration: 23, Loss: 0.218434
# Epoch: 12, Iteration: 25, Loss: 0.208436
# Epoch: 12, Iteration: 27, Loss: 0.119432
# Epoch: 12, Iteration: 29, Loss: 0.339674
# Epoch: 12, Iteration: 31, Loss: 0.272692
# Epoch: 12, Iteration: 33, Loss: 0.090363
# Epoch: 12, Iteration: 35, Loss: 0.202175
# Epoch: 12, Iteration: 37, Loss: 0.098866
# Epoch: 12, Iteration: 39, Loss: 0.270158
# Epoch: 12, Iteration: 41, Loss: 0.395630
# Epoch: 12, Iteration: 43, Loss: 0.106387
# Epoch: 12, Iteration: 45, Loss: 0.122693
# Epoch: 12, Iteration: 47, Loss: 0.168865
# Epoch: 12, Iteration: 49, Loss: 0.144872
# Epoch: 12, Iteration: 51, Loss: 0.067388
# Epoch: 12, Iteration: 53, Loss: 0.240118
# Epoch: 12, Iteration: 55, Loss: 0.421872
# Epoch: 12, Iteration: 57, Loss: 0.194826
# Epoch: 12, Iteration: 59, Loss: 0.176576
# Epoch: 12, Iteration: 61, Loss: 0.182167
# Epoch: 12, Iteration: 63, Loss: 0.174483
# Epoch: 12, Iteration: 65, Loss: 0.235888
# Epoch: 12, Iteration: 67, Loss: 0.231289
# Epoch: 12, Iteration: 69, Loss: 0.090038
# Epoch: 12, Iteration: 71, Loss: 0.142766
# Epoch: 12, Iteration: 73, Loss: 0.138702
# Epoch 12 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1436/1547 (93%)
#
# Epoch: 13, Iteration: 1, Loss: 0.160884
# Epoch: 13, Iteration: 3, Loss: 0.244591
# Epoch: 13, Iteration: 5, Loss: 0.121668
# Epoch: 13, Iteration: 7, Loss: 0.284084
# Epoch: 13, Iteration: 9, Loss: 0.336914
# Epoch: 13, Iteration: 11, Loss: 0.136881
# Epoch: 13, Iteration: 13, Loss: 0.145630
# Epoch: 13, Iteration: 15, Loss: 0.147967
# Epoch: 13, Iteration: 17, Loss: 0.108591
# Epoch: 13, Iteration: 19, Loss: 0.272799
# Epoch: 13, Iteration: 21, Loss: 0.219363
# Epoch: 13, Iteration: 23, Loss: 0.148092
# Epoch: 13, Iteration: 25, Loss: 0.163791
# Epoch: 13, Iteration: 27, Loss: 0.125561
# Epoch: 13, Iteration: 29, Loss: 0.120766
# Epoch: 13, Iteration: 31, Loss: 0.145984
# Epoch: 13, Iteration: 33, Loss: 0.239037
# Epoch: 13, Iteration: 35, Loss: 0.157199
# Epoch: 13, Iteration: 37, Loss: 0.089351
# Epoch: 13, Iteration: 39, Loss: 0.256000
# Epoch: 13, Iteration: 41, Loss: 0.123684
# Epoch: 13, Iteration: 43, Loss: 0.157222
# Epoch: 13, Iteration: 45, Loss: 0.176134
# Epoch: 13, Iteration: 47, Loss: 0.127856
# Epoch: 13, Iteration: 49, Loss: 0.106898
# Epoch: 13, Iteration: 51, Loss: 0.149148
# Epoch: 13, Iteration: 53, Loss: 0.094312
# Epoch: 13, Iteration: 55, Loss: 0.115390
# Epoch: 13, Iteration: 57, Loss: 0.126613
# Epoch: 13, Iteration: 59, Loss: 0.169189
# Epoch: 13, Iteration: 61, Loss: 0.278512
# Epoch: 13, Iteration: 63, Loss: 0.227807
# Epoch: 13, Iteration: 65, Loss: 0.162225
# Epoch: 13, Iteration: 67, Loss: 0.135260
# Epoch: 13, Iteration: 69, Loss: 0.101032
# Epoch: 13, Iteration: 71, Loss: 0.230942
# Epoch: 13, Iteration: 73, Loss: 0.147593
# Epoch 13 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1424/1547 (92%)
#
# Epoch: 14, Iteration: 1, Loss: 0.200323
# Epoch: 14, Iteration: 3, Loss: 0.177177
# Epoch: 14, Iteration: 5, Loss: 0.218362
# Epoch: 14, Iteration: 7, Loss: 0.044191
# Epoch: 14, Iteration: 9, Loss: 0.178299
# Epoch: 14, Iteration: 11, Loss: 0.088029
# Epoch: 14, Iteration: 13, Loss: 0.126529
# Epoch: 14, Iteration: 15, Loss: 0.098685
# Epoch: 14, Iteration: 17, Loss: 0.262695
# Epoch: 14, Iteration: 19, Loss: 0.675673
# Epoch: 14, Iteration: 21, Loss: 0.058212
# Epoch: 14, Iteration: 23, Loss: 0.127968
# Epoch: 14, Iteration: 25, Loss: 0.211500
# Epoch: 14, Iteration: 27, Loss: 0.232787
# Epoch: 14, Iteration: 29, Loss: 0.148940
# Epoch: 14, Iteration: 31, Loss: 0.270304
# Epoch: 14, Iteration: 33, Loss: 0.220180
# Epoch: 14, Iteration: 35, Loss: 0.161022
# Epoch: 14, Iteration: 37, Loss: 0.246952
# Epoch: 14, Iteration: 39, Loss: 0.173374
# Epoch: 14, Iteration: 41, Loss: 0.084102
# Epoch: 14, Iteration: 43, Loss: 0.237660
# Epoch: 14, Iteration: 45, Loss: 0.232505
# Epoch: 14, Iteration: 47, Loss: 0.259152
# Epoch: 14, Iteration: 49, Loss: 0.197885
# Epoch: 14, Iteration: 51, Loss: 0.292937
# Epoch: 14, Iteration: 53, Loss: 0.165725
# Epoch: 14, Iteration: 55, Loss: 0.105254
# Epoch: 14, Iteration: 57, Loss: 0.111431
# Epoch: 14, Iteration: 59, Loss: 0.111403
# Epoch: 14, Iteration: 61, Loss: 0.146128
# Epoch: 14, Iteration: 63, Loss: 0.163335
# Epoch: 14, Iteration: 65, Loss: 0.215635
# Epoch: 14, Iteration: 67, Loss: 0.167684
# Epoch: 14, Iteration: 69, Loss: 0.143144
# Epoch: 14, Iteration: 71, Loss: 0.225342
# Epoch: 14, Iteration: 73, Loss: 0.135112
# Epoch 14 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1426/1547 (92%)
#
# Epoch: 15, Iteration: 1, Loss: 0.121887
# Epoch: 15, Iteration: 3, Loss: 0.082834
# Epoch: 15, Iteration: 5, Loss: 0.124751
# Epoch: 15, Iteration: 7, Loss: 0.125177
# Epoch: 15, Iteration: 9, Loss: 0.093811
# Epoch: 15, Iteration: 11, Loss: 0.147379
# Epoch: 15, Iteration: 13, Loss: 0.177111
# Epoch: 15, Iteration: 15, Loss: 0.082166
# Epoch: 15, Iteration: 17, Loss: 0.215106
# Epoch: 15, Iteration: 19, Loss: 0.066022
# Epoch: 15, Iteration: 21, Loss: 0.178566
# Epoch: 15, Iteration: 23, Loss: 0.096872
# Epoch: 15, Iteration: 25, Loss: 0.203914
# Epoch: 15, Iteration: 27, Loss: 0.078769
# Epoch: 15, Iteration: 29, Loss: 0.153477
# Epoch: 15, Iteration: 31, Loss: 0.285368
# Epoch: 15, Iteration: 33, Loss: 0.205106
# Epoch: 15, Iteration: 35, Loss: 0.192987
# Epoch: 15, Iteration: 37, Loss: 0.121164
# Epoch: 15, Iteration: 39, Loss: 0.340090
# Epoch: 15, Iteration: 41, Loss: 0.182280
# Epoch: 15, Iteration: 43, Loss: 0.228525
# Epoch: 15, Iteration: 45, Loss: 0.147623
# Epoch: 15, Iteration: 47, Loss: 0.125632
# Epoch: 15, Iteration: 49, Loss: 0.135830
# Epoch: 15, Iteration: 51, Loss: 0.157776
# Epoch: 15, Iteration: 53, Loss: 0.210886
# Epoch: 15, Iteration: 55, Loss: 0.153972
# Epoch: 15, Iteration: 57, Loss: 0.220988
# Epoch: 15, Iteration: 59, Loss: 0.184780
# Epoch: 15, Iteration: 61, Loss: 0.181342
# Epoch: 15, Iteration: 63, Loss: 0.143876
# Epoch: 15, Iteration: 65, Loss: 0.281829
# Epoch: 15, Iteration: 67, Loss: 0.109195
# Epoch: 15, Iteration: 69, Loss: 0.174322
# Epoch: 15, Iteration: 71, Loss: 0.131273
# Epoch: 15, Iteration: 73, Loss: 0.259228
# Epoch 15 completed.
#
# Test set: Average loss: 0.0002, Accuracy: 1435/1547 (93%)
#
# Epoch: 16, Iteration: 1, Loss: 0.196546
# Epoch: 16, Iteration: 3, Loss: 0.278581
# Epoch: 16, Iteration: 5, Loss: 0.195194
# Epoch: 16, Iteration: 7, Loss: 0.137686
# Epoch: 16, Iteration: 9, Loss: 0.183176
# Epoch: 16, Iteration: 11, Loss: 0.175659
# Epoch: 16, Iteration: 13, Loss: 0.354974
# Epoch: 16, Iteration: 15, Loss: 0.087911
# Epoch: 16, Iteration: 17, Loss: 0.073795
# Epoch: 16, Iteration: 19, Loss: 0.105409
# Epoch: 16, Iteration: 21, Loss: 0.144908
# Epoch: 16, Iteration: 23, Loss: 0.159505
# Epoch: 16, Iteration: 25, Loss: 0.296323
# Epoch: 16, Iteration: 27, Loss: 0.121230
# Epoch: 16, Iteration: 29, Loss: 0.166529
# Epoch: 16, Iteration: 31, Loss: 0.171891
# Epoch: 16, Iteration: 33, Loss: 0.161882
# Epoch: 16, Iteration: 35, Loss: 0.145854
# Epoch: 16, Iteration: 37, Loss: 0.194504
# Epoch: 16, Iteration: 39, Loss: 0.172675
# Epoch: 16, Iteration: 41, Loss: 0.220435
# Epoch: 16, Iteration: 43, Loss: 0.137362
# Epoch: 16, Iteration: 45, Loss: 0.195181
# Epoch: 16, Iteration: 47, Loss: 0.095109
# Epoch: 16, Iteration: 49, Loss: 0.088829
# Epoch: 16, Iteration: 51, Loss: 0.168041
# Epoch: 16, Iteration: 53, Loss: 0.140853
# Epoch: 16, Iteration: 55, Loss: 0.240080
# Epoch: 16, Iteration: 57, Loss: 0.069453
# Epoch: 16, Iteration: 59, Loss: 0.133520
# Epoch: 16, Iteration: 61, Loss: 0.083897
# Epoch: 16, Iteration: 63, Loss: 0.144740
# Epoch: 16, Iteration: 65, Loss: 0.167769
# Epoch: 16, Iteration: 67, Loss: 0.143889
# Epoch: 16, Iteration: 69, Loss: 0.119830
# Epoch: 16, Iteration: 71, Loss: 0.098753
# Epoch: 16, Iteration: 73, Loss: 0.142419
# Epoch 16 completed.
#
# Test set: Average loss: 0.0002, Accuracy: 1444/1547 (93%)
#
# Epoch: 17, Iteration: 1, Loss: 0.148937
# Epoch: 17, Iteration: 3, Loss: 0.170146
# Epoch: 17, Iteration: 5, Loss: 0.121802
# Epoch: 17, Iteration: 7, Loss: 0.157822
# Epoch: 17, Iteration: 9, Loss: 0.149137
# Epoch: 17, Iteration: 11, Loss: 0.134813
# Epoch: 17, Iteration: 13, Loss: 0.104918
# Epoch: 17, Iteration: 15, Loss: 0.207316
# Epoch: 17, Iteration: 17, Loss: 0.122496
# Epoch: 17, Iteration: 19, Loss: 0.182969
# Epoch: 17, Iteration: 21, Loss: 0.209521
# Epoch: 17, Iteration: 23, Loss: 0.153324
# Epoch: 17, Iteration: 25, Loss: 0.217076
# Epoch: 17, Iteration: 27, Loss: 0.153880
# Epoch: 17, Iteration: 29, Loss: 0.185917
# Epoch: 17, Iteration: 31, Loss: 0.144696
# Epoch: 17, Iteration: 33, Loss: 0.083340
# Epoch: 17, Iteration: 35, Loss: 0.123033
# Epoch: 17, Iteration: 37, Loss: 0.096922
# Epoch: 17, Iteration: 39, Loss: 0.122136
# Epoch: 17, Iteration: 41, Loss: 0.182004
# Epoch: 17, Iteration: 43, Loss: 0.104897
# Epoch: 17, Iteration: 45, Loss: 0.137194
# Epoch: 17, Iteration: 47, Loss: 0.124153
# Epoch: 17, Iteration: 49, Loss: 0.093484
# Epoch: 17, Iteration: 51, Loss: 0.074742
# Epoch: 17, Iteration: 53, Loss: 0.100464
# Epoch: 17, Iteration: 55, Loss: 0.194830
# Epoch: 17, Iteration: 57, Loss: 0.187918
# Epoch: 17, Iteration: 59, Loss: 0.120377
# Epoch: 17, Iteration: 61, Loss: 0.148044
# Epoch: 17, Iteration: 63, Loss: 0.115020
# Epoch: 17, Iteration: 65, Loss: 0.107814
# Epoch: 17, Iteration: 67, Loss: 0.158403
# Epoch: 17, Iteration: 69, Loss: 0.120467
# Epoch: 17, Iteration: 71, Loss: 0.085955
# Epoch: 17, Iteration: 73, Loss: 0.302577
# Epoch 17 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1438/1547 (93%)
#
# Epoch: 18, Iteration: 1, Loss: 0.245330
# Epoch: 18, Iteration: 3, Loss: 0.160498
# Epoch: 18, Iteration: 5, Loss: 0.124690
# Epoch: 18, Iteration: 7, Loss: 0.141315
# Epoch: 18, Iteration: 9, Loss: 0.230199
# Epoch: 18, Iteration: 11, Loss: 0.172960
# Epoch: 18, Iteration: 13, Loss: 0.087306
# Epoch: 18, Iteration: 15, Loss: 0.200725
# Epoch: 18, Iteration: 17, Loss: 0.063322
# Epoch: 18, Iteration: 19, Loss: 0.321962
# Epoch: 18, Iteration: 21, Loss: 0.158644
# Epoch: 18, Iteration: 23, Loss: 0.127458
# Epoch: 18, Iteration: 25, Loss: 0.196874
# Epoch: 18, Iteration: 27, Loss: 0.229511
# Epoch: 18, Iteration: 29, Loss: 0.220968
# Epoch: 18, Iteration: 31, Loss: 0.208633
# Epoch: 18, Iteration: 33, Loss: 0.087059
# Epoch: 18, Iteration: 35, Loss: 0.163254
# Epoch: 18, Iteration: 37, Loss: 0.119033
# Epoch: 18, Iteration: 39, Loss: 0.177738
# Epoch: 18, Iteration: 41, Loss: 0.100326
# Epoch: 18, Iteration: 43, Loss: 0.168813
# Epoch: 18, Iteration: 45, Loss: 0.138586
# Epoch: 18, Iteration: 47, Loss: 0.156877
# Epoch: 18, Iteration: 49, Loss: 0.040740
# Epoch: 18, Iteration: 51, Loss: 0.255070
# Epoch: 18, Iteration: 53, Loss: 0.176905
# Epoch: 18, Iteration: 55, Loss: 0.086414
# Epoch: 18, Iteration: 57, Loss: 0.109375
# Epoch: 18, Iteration: 59, Loss: 0.095867
# Epoch: 18, Iteration: 61, Loss: 0.084242
# Epoch: 18, Iteration: 63, Loss: 0.088102
# Epoch: 18, Iteration: 65, Loss: 0.154941
# Epoch: 18, Iteration: 67, Loss: 0.138916
# Epoch: 18, Iteration: 69, Loss: 0.216761
# Epoch: 18, Iteration: 71, Loss: 0.285817
# Epoch: 18, Iteration: 73, Loss: 0.087315
# Epoch 18 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1436/1547 (93%)
#
# Epoch: 19, Iteration: 1, Loss: 0.082409
# Epoch: 19, Iteration: 3, Loss: 0.074442
# Epoch: 19, Iteration: 5, Loss: 0.094897
# Epoch: 19, Iteration: 7, Loss: 0.111430
# Epoch: 19, Iteration: 9, Loss: 0.154877
# Epoch: 19, Iteration: 11, Loss: 0.178097
# Epoch: 19, Iteration: 13, Loss: 0.174011
# Epoch: 19, Iteration: 15, Loss: 0.105501
# Epoch: 19, Iteration: 17, Loss: 0.131149
# Epoch: 19, Iteration: 19, Loss: 0.153469
# Epoch: 19, Iteration: 21, Loss: 0.086095
# Epoch: 19, Iteration: 23, Loss: 0.126357
# Epoch: 19, Iteration: 25, Loss: 0.046934
# Epoch: 19, Iteration: 27, Loss: 0.115507
# Epoch: 19, Iteration: 29, Loss: 0.107824
# Epoch: 19, Iteration: 31, Loss: 0.088892
# Epoch: 19, Iteration: 33, Loss: 0.200061
# Epoch: 19, Iteration: 35, Loss: 0.234970
# Epoch: 19, Iteration: 37, Loss: 0.180374
# Epoch: 19, Iteration: 39, Loss: 0.115057
# Epoch: 19, Iteration: 41, Loss: 0.083138
# Epoch: 19, Iteration: 43, Loss: 0.225594
# Epoch: 19, Iteration: 45, Loss: 0.323966
# Epoch: 19, Iteration: 47, Loss: 0.112367
# Epoch: 19, Iteration: 49, Loss: 0.129930
# Epoch: 19, Iteration: 51, Loss: 0.216476
# Epoch: 19, Iteration: 53, Loss: 0.229278
# Epoch: 19, Iteration: 55, Loss: 0.142451
# Epoch: 19, Iteration: 57, Loss: 0.075000
# Epoch: 19, Iteration: 59, Loss: 0.211013
# Epoch: 19, Iteration: 61, Loss: 0.170369
# Epoch: 19, Iteration: 63, Loss: 0.174580
# Epoch: 19, Iteration: 65, Loss: 0.170184
# Epoch: 19, Iteration: 67, Loss: 0.052174
# Epoch: 19, Iteration: 69, Loss: 0.117355
# Epoch: 19, Iteration: 71, Loss: 0.092883
# Epoch: 19, Iteration: 73, Loss: 0.087364
# Epoch 19 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1434/1547 (93%)
#
# Epoch: 20, Iteration: 1, Loss: 0.130200
# Epoch: 20, Iteration: 3, Loss: 0.165799
# Epoch: 20, Iteration: 5, Loss: 0.158182
# Epoch: 20, Iteration: 7, Loss: 0.201367
# Epoch: 20, Iteration: 9, Loss: 0.169596
# Epoch: 20, Iteration: 11, Loss: 0.181444
# Epoch: 20, Iteration: 13, Loss: 0.173923
# Epoch: 20, Iteration: 15, Loss: 0.200406
# Epoch: 20, Iteration: 17, Loss: 0.262642
# Epoch: 20, Iteration: 19, Loss: 0.059163
# Epoch: 20, Iteration: 21, Loss: 0.138240
# Epoch: 20, Iteration: 23, Loss: 0.095053
# Epoch: 20, Iteration: 25, Loss: 0.121426
# Epoch: 20, Iteration: 27, Loss: 0.140792
# Epoch: 20, Iteration: 29, Loss: 0.235269
# Epoch: 20, Iteration: 31, Loss: 0.121979
# Epoch: 20, Iteration: 33, Loss: 0.176393
# Epoch: 20, Iteration: 35, Loss: 0.153107
# Epoch: 20, Iteration: 37, Loss: 0.108713
# Epoch: 20, Iteration: 39, Loss: 0.138806
# Epoch: 20, Iteration: 41, Loss: 0.060607
# Epoch: 20, Iteration: 43, Loss: 0.234653
# Epoch: 20, Iteration: 45, Loss: 0.139941
# Epoch: 20, Iteration: 47, Loss: 0.210284
# Epoch: 20, Iteration: 49, Loss: 0.128762
# Epoch: 20, Iteration: 51, Loss: 0.081282
# Epoch: 20, Iteration: 53, Loss: 0.151855
# Epoch: 20, Iteration: 55, Loss: 0.162711
# Epoch: 20, Iteration: 57, Loss: 0.114988
# Epoch: 20, Iteration: 59, Loss: 0.113932
# Epoch: 20, Iteration: 61, Loss: 0.147922
# Epoch: 20, Iteration: 63, Loss: 0.258000
# Epoch: 20, Iteration: 65, Loss: 0.297258
# Epoch: 20, Iteration: 67, Loss: 0.157084
# Epoch: 20, Iteration: 69, Loss: 0.168871
# Epoch: 20, Iteration: 71, Loss: 0.193405
# Epoch: 20, Iteration: 73, Loss: 0.115275
# Epoch 20 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1410/1547 (91%)
#
# Epoch: 21, Iteration: 1, Loss: 0.161482
# Epoch: 21, Iteration: 3, Loss: 0.151330
# Epoch: 21, Iteration: 5, Loss: 0.119162
# Epoch: 21, Iteration: 7, Loss: 0.162917
# Epoch: 21, Iteration: 9, Loss: 0.096426
# Epoch: 21, Iteration: 11, Loss: 0.190730
# Epoch: 21, Iteration: 13, Loss: 0.108755
# Epoch: 21, Iteration: 15, Loss: 0.154145
# Epoch: 21, Iteration: 17, Loss: 0.097370
# Epoch: 21, Iteration: 19, Loss: 0.135349
# Epoch: 21, Iteration: 21, Loss: 0.072449
# Epoch: 21, Iteration: 23, Loss: 0.161850
# Epoch: 21, Iteration: 25, Loss: 0.148659
# Epoch: 21, Iteration: 27, Loss: 0.177913
# Epoch: 21, Iteration: 29, Loss: 0.140079
# Epoch: 21, Iteration: 31, Loss: 0.126339
# Epoch: 21, Iteration: 33, Loss: 0.131302
# Epoch: 21, Iteration: 35, Loss: 0.199886
# Epoch: 21, Iteration: 37, Loss: 0.289963
# Epoch: 21, Iteration: 39, Loss: 0.104336
# Epoch: 21, Iteration: 41, Loss: 0.190789
# Epoch: 21, Iteration: 43, Loss: 0.191590
# Epoch: 21, Iteration: 45, Loss: 0.135239
# Epoch: 21, Iteration: 47, Loss: 0.106992
# Epoch: 21, Iteration: 49, Loss: 0.126424
# Epoch: 21, Iteration: 51, Loss: 0.112997
# Epoch: 21, Iteration: 53, Loss: 0.144761
# Epoch: 21, Iteration: 55, Loss: 0.234503
# Epoch: 21, Iteration: 57, Loss: 0.137164
# Epoch: 21, Iteration: 59, Loss: 0.143384
# Epoch: 21, Iteration: 61, Loss: 0.090247
# Epoch: 21, Iteration: 63, Loss: 0.296584
# Epoch: 21, Iteration: 65, Loss: 0.129186
# Epoch: 21, Iteration: 67, Loss: 0.155384
# Epoch: 21, Iteration: 69, Loss: 0.211668
# Epoch: 21, Iteration: 71, Loss: 0.189581
# Epoch: 21, Iteration: 73, Loss: 0.321699
# Epoch 21 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1404/1547 (91%)
#
# Epoch: 22, Iteration: 1, Loss: 0.113980
# Epoch: 22, Iteration: 3, Loss: 0.205397
# Epoch: 22, Iteration: 5, Loss: 0.249757
# Epoch: 22, Iteration: 7, Loss: 0.248103
# Epoch: 22, Iteration: 9, Loss: 0.122667
# Epoch: 22, Iteration: 11, Loss: 0.331370
# Epoch: 22, Iteration: 13, Loss: 0.147508
# Epoch: 22, Iteration: 15, Loss: 0.183334
# Epoch: 22, Iteration: 17, Loss: 0.219801
# Epoch: 22, Iteration: 19, Loss: 0.169015
# Epoch: 22, Iteration: 21, Loss: 0.219603
# Epoch: 22, Iteration: 23, Loss: 0.105894
# Epoch: 22, Iteration: 25, Loss: 0.054249
# Epoch: 22, Iteration: 27, Loss: 0.120892
# Epoch: 22, Iteration: 29, Loss: 0.106561
# Epoch: 22, Iteration: 31, Loss: 0.140933
# Epoch: 22, Iteration: 33, Loss: 0.096530
# Epoch: 22, Iteration: 35, Loss: 0.097071
# Epoch: 22, Iteration: 37, Loss: 0.187537
# Epoch: 22, Iteration: 39, Loss: 0.132946
# Epoch: 22, Iteration: 41, Loss: 0.141313
# Epoch: 22, Iteration: 43, Loss: 0.059147
# Epoch: 22, Iteration: 45, Loss: 0.106428
# Epoch: 22, Iteration: 47, Loss: 0.178484
# Epoch: 22, Iteration: 49, Loss: 0.116036
# Epoch: 22, Iteration: 51, Loss: 0.244297
# Epoch: 22, Iteration: 53, Loss: 0.191363
# Epoch: 22, Iteration: 55, Loss: 0.166606
# Epoch: 22, Iteration: 57, Loss: 0.346957
# Epoch: 22, Iteration: 59, Loss: 0.160357
# Epoch: 22, Iteration: 61, Loss: 0.225519
# Epoch: 22, Iteration: 63, Loss: 0.137803
# Epoch: 22, Iteration: 65, Loss: 0.145205
# Epoch: 22, Iteration: 67, Loss: 0.116128
# Epoch: 22, Iteration: 69, Loss: 0.136000
# Epoch: 22, Iteration: 71, Loss: 0.388061
# Epoch: 22, Iteration: 73, Loss: 0.343786
# Epoch 22 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1418/1547 (92%)
#
# Epoch: 23, Iteration: 1, Loss: 0.079081
# Epoch: 23, Iteration: 3, Loss: 0.127998
# Epoch: 23, Iteration: 5, Loss: 0.161197
# Epoch: 23, Iteration: 7, Loss: 0.094167
# Epoch: 23, Iteration: 9, Loss: 0.279839
# Epoch: 23, Iteration: 11, Loss: 0.155930
# Epoch: 23, Iteration: 13, Loss: 0.093263
# Epoch: 23, Iteration: 15, Loss: 0.037801
# Epoch: 23, Iteration: 17, Loss: 0.044695
# Epoch: 23, Iteration: 19, Loss: 0.269149
# Epoch: 23, Iteration: 21, Loss: 0.048095
# Epoch: 23, Iteration: 23, Loss: 0.190624
# Epoch: 23, Iteration: 25, Loss: 0.197712
# Epoch: 23, Iteration: 27, Loss: 0.044393
# Epoch: 23, Iteration: 29, Loss: 0.150617
# Epoch: 23, Iteration: 31, Loss: 0.077114
# Epoch: 23, Iteration: 33, Loss: 0.098839
# Epoch: 23, Iteration: 35, Loss: 0.345955
# Epoch: 23, Iteration: 37, Loss: 0.107260
# Epoch: 23, Iteration: 39, Loss: 0.273796
# Epoch: 23, Iteration: 41, Loss: 0.171146
# Epoch: 23, Iteration: 43, Loss: 0.094072
# Epoch: 23, Iteration: 45, Loss: 0.214747
# Epoch: 23, Iteration: 47, Loss: 0.102357
# Epoch: 23, Iteration: 49, Loss: 0.093092
# Epoch: 23, Iteration: 51, Loss: 0.105473
# Epoch: 23, Iteration: 53, Loss: 0.065968
# Epoch: 23, Iteration: 55, Loss: 0.101721
# Epoch: 23, Iteration: 57, Loss: 0.161316
# Epoch: 23, Iteration: 59, Loss: 0.161208
# Epoch: 23, Iteration: 61, Loss: 0.140572
# Epoch: 23, Iteration: 63, Loss: 0.129069
# Epoch: 23, Iteration: 65, Loss: 0.131461
# Epoch: 23, Iteration: 67, Loss: 0.154125
# Epoch: 23, Iteration: 69, Loss: 0.143861
# Epoch: 23, Iteration: 71, Loss: 0.109856
# Epoch: 23, Iteration: 73, Loss: 0.093524
# Epoch 23 completed.
#
# Test set: Average loss: 0.0002, Accuracy: 1437/1547 (93%)
#
# Epoch: 24, Iteration: 1, Loss: 0.090643
# Epoch: 24, Iteration: 3, Loss: 0.176957
# Epoch: 24, Iteration: 5, Loss: 0.161029
# Epoch: 24, Iteration: 7, Loss: 0.092734
# Epoch: 24, Iteration: 9, Loss: 0.129985
# Epoch: 24, Iteration: 11, Loss: 0.256257
# Epoch: 24, Iteration: 13, Loss: 0.097155
# Epoch: 24, Iteration: 15, Loss: 0.105221
# Epoch: 24, Iteration: 17, Loss: 0.133320
# Epoch: 24, Iteration: 19, Loss: 0.129068
# Epoch: 24, Iteration: 21, Loss: 0.153029
# Epoch: 24, Iteration: 23, Loss: 0.148330
# Epoch: 24, Iteration: 25, Loss: 0.161170
# Epoch: 24, Iteration: 27, Loss: 0.148509
# Epoch: 24, Iteration: 29, Loss: 0.106753
# Epoch: 24, Iteration: 31, Loss: 0.100152
# Epoch: 24, Iteration: 33, Loss: 0.110427
# Epoch: 24, Iteration: 35, Loss: 0.079852
# Epoch: 24, Iteration: 37, Loss: 0.166262
# Epoch: 24, Iteration: 39, Loss: 0.128047
# Epoch: 24, Iteration: 41, Loss: 0.066519
# Epoch: 24, Iteration: 43, Loss: 0.155674
# Epoch: 24, Iteration: 45, Loss: 0.111263
# Epoch: 24, Iteration: 47, Loss: 0.207961
# Epoch: 24, Iteration: 49, Loss: 0.088249
# Epoch: 24, Iteration: 51, Loss: 0.037348
# Epoch: 24, Iteration: 53, Loss: 0.231233
# Epoch: 24, Iteration: 55, Loss: 0.095812
# Epoch: 24, Iteration: 57, Loss: 0.159794
# Epoch: 24, Iteration: 59, Loss: 0.122862
# Epoch: 24, Iteration: 61, Loss: 0.162277
# Epoch: 24, Iteration: 63, Loss: 0.219678
# Epoch: 24, Iteration: 65, Loss: 0.120362
# Epoch: 24, Iteration: 67, Loss: 0.102915
# Epoch: 24, Iteration: 69, Loss: 0.081233
# Epoch: 24, Iteration: 71, Loss: 0.176822
# Epoch: 24, Iteration: 73, Loss: 0.183660
# Epoch 24 completed.
#
# Test set: Average loss: 0.0002, Accuracy: 1443/1547 (93%)
#
# Epoch: 25, Iteration: 1, Loss: 0.096584
# Epoch: 25, Iteration: 3, Loss: 0.254462
# Epoch: 25, Iteration: 5, Loss: 0.116573
# Epoch: 25, Iteration: 7, Loss: 0.156922
# Epoch: 25, Iteration: 9, Loss: 0.204698
# Epoch: 25, Iteration: 11, Loss: 0.169277
# Epoch: 25, Iteration: 13, Loss: 0.049939
# Epoch: 25, Iteration: 15, Loss: 0.103681
# Epoch: 25, Iteration: 17, Loss: 0.236291
# Epoch: 25, Iteration: 19, Loss: 0.116522
# Epoch: 25, Iteration: 21, Loss: 0.098512
# Epoch: 25, Iteration: 23, Loss: 0.086440
# Epoch: 25, Iteration: 25, Loss: 0.104669
# Epoch: 25, Iteration: 27, Loss: 0.158044
# Epoch: 25, Iteration: 29, Loss: 0.094572
# Epoch: 25, Iteration: 31, Loss: 0.251022
# Epoch: 25, Iteration: 33, Loss: 0.434412
# Epoch: 25, Iteration: 35, Loss: 0.079945
# Epoch: 25, Iteration: 37, Loss: 0.167438
# Epoch: 25, Iteration: 39, Loss: 0.127555
# Epoch: 25, Iteration: 41, Loss: 0.238331
# Epoch: 25, Iteration: 43, Loss: 0.155819
# Epoch: 25, Iteration: 45, Loss: 0.185174
# Epoch: 25, Iteration: 47, Loss: 0.188828
# Epoch: 25, Iteration: 49, Loss: 0.143768
# Epoch: 25, Iteration: 51, Loss: 0.213550
# Epoch: 25, Iteration: 53, Loss: 0.121006
# Epoch: 25, Iteration: 55, Loss: 0.169441
# Epoch: 25, Iteration: 57, Loss: 0.100807
# Epoch: 25, Iteration: 59, Loss: 0.134737
# Epoch: 25, Iteration: 61, Loss: 0.209136
# Epoch: 25, Iteration: 63, Loss: 0.115554
# Epoch: 25, Iteration: 65, Loss: 0.137661
# Epoch: 25, Iteration: 67, Loss: 0.065870
# Epoch: 25, Iteration: 69, Loss: 0.123866
# Epoch: 25, Iteration: 71, Loss: 0.169245
# Epoch: 25, Iteration: 73, Loss: 0.104012
# Epoch 25 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1436/1547 (93%)
#
# Epoch: 26, Iteration: 1, Loss: 0.092754
# Epoch: 26, Iteration: 3, Loss: 0.146602
# Epoch: 26, Iteration: 5, Loss: 0.138057
# Epoch: 26, Iteration: 7, Loss: 0.039423
# Epoch: 26, Iteration: 9, Loss: 0.108270
# Epoch: 26, Iteration: 11, Loss: 0.049245
# Epoch: 26, Iteration: 13, Loss: 0.073020
# Epoch: 26, Iteration: 15, Loss: 0.085811
# Epoch: 26, Iteration: 17, Loss: 0.248695
# Epoch: 26, Iteration: 19, Loss: 0.105625
# Epoch: 26, Iteration: 21, Loss: 0.241665
# Epoch: 26, Iteration: 23, Loss: 0.161187
# Epoch: 26, Iteration: 25, Loss: 0.087798
# Epoch: 26, Iteration: 27, Loss: 0.150967
# Epoch: 26, Iteration: 29, Loss: 0.109458
# Epoch: 26, Iteration: 31, Loss: 0.140623
# Epoch: 26, Iteration: 33, Loss: 0.075580
# Epoch: 26, Iteration: 35, Loss: 0.147642
# Epoch: 26, Iteration: 37, Loss: 0.115943
# Epoch: 26, Iteration: 39, Loss: 0.067515
# Epoch: 26, Iteration: 41, Loss: 0.072351
# Epoch: 26, Iteration: 43, Loss: 0.314111
# Epoch: 26, Iteration: 45, Loss: 0.185562
# Epoch: 26, Iteration: 47, Loss: 0.143415
# Epoch: 26, Iteration: 49, Loss: 0.199568
# Epoch: 26, Iteration: 51, Loss: 0.079438
# Epoch: 26, Iteration: 53, Loss: 0.083313
# Epoch: 26, Iteration: 55, Loss: 0.074080
# Epoch: 26, Iteration: 57, Loss: 0.125007
# Epoch: 26, Iteration: 59, Loss: 0.227751
# Epoch: 26, Iteration: 61, Loss: 0.115238
# Epoch: 26, Iteration: 63, Loss: 0.188394
# Epoch: 26, Iteration: 65, Loss: 0.074512
# Epoch: 26, Iteration: 67, Loss: 0.277755
# Epoch: 26, Iteration: 69, Loss: 0.097819
# Epoch: 26, Iteration: 71, Loss: 0.055874
# Epoch: 26, Iteration: 73, Loss: 0.033939
# Epoch 26 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1438/1547 (93%)
#
# Epoch: 27, Iteration: 1, Loss: 0.118831
# Epoch: 27, Iteration: 3, Loss: 0.229493
# Epoch: 27, Iteration: 5, Loss: 0.160725
# Epoch: 27, Iteration: 7, Loss: 0.033309
# Epoch: 27, Iteration: 9, Loss: 0.161041
# Epoch: 27, Iteration: 11, Loss: 0.151512
# Epoch: 27, Iteration: 13, Loss: 0.090035
# Epoch: 27, Iteration: 15, Loss: 0.074003
# Epoch: 27, Iteration: 17, Loss: 0.148040
# Epoch: 27, Iteration: 19, Loss: 0.134038
# Epoch: 27, Iteration: 21, Loss: 0.144707
# Epoch: 27, Iteration: 23, Loss: 0.082480
# Epoch: 27, Iteration: 25, Loss: 0.084875
# Epoch: 27, Iteration: 27, Loss: 0.175360
# Epoch: 27, Iteration: 29, Loss: 0.150771
# Epoch: 27, Iteration: 31, Loss: 0.118261
# Epoch: 27, Iteration: 33, Loss: 0.125585
# Epoch: 27, Iteration: 35, Loss: 0.043536
# Epoch: 27, Iteration: 37, Loss: 0.112276
# Epoch: 27, Iteration: 39, Loss: 0.235145
# Epoch: 27, Iteration: 41, Loss: 0.100809
# Epoch: 27, Iteration: 43, Loss: 0.133107
# Epoch: 27, Iteration: 45, Loss: 0.129741
# Epoch: 27, Iteration: 47, Loss: 0.201596
# Epoch: 27, Iteration: 49, Loss: 0.121831
# Epoch: 27, Iteration: 51, Loss: 0.107927
# Epoch: 27, Iteration: 53, Loss: 0.193932
# Epoch: 27, Iteration: 55, Loss: 0.133552
# Epoch: 27, Iteration: 57, Loss: 0.150556
# Epoch: 27, Iteration: 59, Loss: 0.114878
# Epoch: 27, Iteration: 61, Loss: 0.091921
# Epoch: 27, Iteration: 63, Loss: 0.219485
# Epoch: 27, Iteration: 65, Loss: 0.121630
# Epoch: 27, Iteration: 67, Loss: 0.193956
# Epoch: 27, Iteration: 69, Loss: 0.130546
# Epoch: 27, Iteration: 71, Loss: 0.132757
# Epoch: 27, Iteration: 73, Loss: 0.122851
# Epoch 27 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1438/1547 (93%)
#
# Epoch: 28, Iteration: 1, Loss: 0.161371
# Epoch: 28, Iteration: 3, Loss: 0.074565
# Epoch: 28, Iteration: 5, Loss: 0.101060
# Epoch: 28, Iteration: 7, Loss: 0.025184
# Epoch: 28, Iteration: 9, Loss: 0.098158
# Epoch: 28, Iteration: 11, Loss: 0.101987
# Epoch: 28, Iteration: 13, Loss: 0.136556
# Epoch: 28, Iteration: 15, Loss: 0.041505
# Epoch: 28, Iteration: 17, Loss: 0.121197
# Epoch: 28, Iteration: 19, Loss: 0.198788
# Epoch: 28, Iteration: 21, Loss: 0.298074
# Epoch: 28, Iteration: 23, Loss: 0.031995
# Epoch: 28, Iteration: 25, Loss: 0.147305
# Epoch: 28, Iteration: 27, Loss: 0.111985
# Epoch: 28, Iteration: 29, Loss: 0.084592
# Epoch: 28, Iteration: 31, Loss: 0.067457
# Epoch: 28, Iteration: 33, Loss: 0.092177
# Epoch: 28, Iteration: 35, Loss: 0.064858
# Epoch: 28, Iteration: 37, Loss: 0.172463
# Epoch: 28, Iteration: 39, Loss: 0.178793
# Epoch: 28, Iteration: 41, Loss: 0.116211
# Epoch: 28, Iteration: 43, Loss: 0.189242
# Epoch: 28, Iteration: 45, Loss: 0.166919
# Epoch: 28, Iteration: 47, Loss: 0.355260
# Epoch: 28, Iteration: 49, Loss: 0.125765
# Epoch: 28, Iteration: 51, Loss: 0.206387
# Epoch: 28, Iteration: 53, Loss: 0.196788
# Epoch: 28, Iteration: 55, Loss: 0.120363
# Epoch: 28, Iteration: 57, Loss: 0.194475
# Epoch: 28, Iteration: 59, Loss: 0.075733
# Epoch: 28, Iteration: 61, Loss: 0.153454
# Epoch: 28, Iteration: 63, Loss: 0.066677
# Epoch: 28, Iteration: 65, Loss: 0.207545
# Epoch: 28, Iteration: 67, Loss: 0.084068
# Epoch: 28, Iteration: 69, Loss: 0.150137
# Epoch: 28, Iteration: 71, Loss: 0.041569
# Epoch: 28, Iteration: 73, Loss: 0.075020
# Epoch 28 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1444/1547 (93%)
#
# Epoch: 29, Iteration: 1, Loss: 0.091411
# Epoch: 29, Iteration: 3, Loss: 0.070234
# Epoch: 29, Iteration: 5, Loss: 0.155791
# Epoch: 29, Iteration: 7, Loss: 0.084481
# Epoch: 29, Iteration: 9, Loss: 0.070231
# Epoch: 29, Iteration: 11, Loss: 0.069436
# Epoch: 29, Iteration: 13, Loss: 0.205644
# Epoch: 29, Iteration: 15, Loss: 0.112144
# Epoch: 29, Iteration: 17, Loss: 0.293777
# Epoch: 29, Iteration: 19, Loss: 0.094116
# Epoch: 29, Iteration: 21, Loss: 0.096869
# Epoch: 29, Iteration: 23, Loss: 0.093066
# Epoch: 29, Iteration: 25, Loss: 0.072977
# Epoch: 29, Iteration: 27, Loss: 0.153965
# Epoch: 29, Iteration: 29, Loss: 0.071175
# Epoch: 29, Iteration: 31, Loss: 0.118287
# Epoch: 29, Iteration: 33, Loss: 0.144631
# Epoch: 29, Iteration: 35, Loss: 0.065322
# Epoch: 29, Iteration: 37, Loss: 0.051086
# Epoch: 29, Iteration: 39, Loss: 0.061984
# Epoch: 29, Iteration: 41, Loss: 0.057632
# Epoch: 29, Iteration: 43, Loss: 0.126787
# Epoch: 29, Iteration: 45, Loss: 0.128507
# Epoch: 29, Iteration: 47, Loss: 0.220359
# Epoch: 29, Iteration: 49, Loss: 0.160731
# Epoch: 29, Iteration: 51, Loss: 0.102360
# Epoch: 29, Iteration: 53, Loss: 0.109144
# Epoch: 29, Iteration: 55, Loss: 0.031749
# Epoch: 29, Iteration: 57, Loss: 0.154812
# Epoch: 29, Iteration: 59, Loss: 0.096346
# Epoch: 29, Iteration: 61, Loss: 0.181798
# Epoch: 29, Iteration: 63, Loss: 0.033758
# Epoch: 29, Iteration: 65, Loss: 0.051744
# Epoch: 29, Iteration: 67, Loss: 0.067852
# Epoch: 29, Iteration: 69, Loss: 0.119149
# Epoch: 29, Iteration: 71, Loss: 0.148418
# Epoch: 29, Iteration: 73, Loss: 0.193678
# Epoch 29 completed.
#
# Test set: Average loss: 0.0003, Accuracy: 1435/1547 (93%)

# %%
# Save the trained model
model_save_path = '/content/heatmaps_model.pth'  # Path where you want to save the model
torch.save(model.state_dict(), model_save_path)
print(f'Model saved to {model_save_path}')
# Out:
# Model saved to /content/heatmaps_model.pth

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import torch.nn.functional as F  # For softmax

# Load the trained model
model = CNN_GSGD(input_size=input_size, num_classes=len(full_dataset.classes)).to(device)
model.load_state_dict(torch.load('/content/heatmaps_model.pth'))
model.eval()

# Get predictions and true labels for the test set
all_preds = []
all_labels = []
all_preds_prob = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        _, preds = torch.max(output, 1)  # Get predictions
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(target.cpu().numpy())
        all_preds_prob.extend(F.softmax(output, dim=1).cpu().numpy())  # Store probabilities

# Classification Report
print("Classification Report:")
print(classification_report(all_labels, all_preds))

# Confusion Matrix
cf_matrix = confusion_matrix(all_labels, all_preds)

# Visualizing Confusion Matrix
plt.figure(figsize=(8, 6))
plt.imshow(cf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
classes = list(full_dataset.classes)  # Assuming the class labels are present in the dataset
plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Add annotations to the confusion matrix
for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, str(cf_matrix[i, j]), ha='center', va='center', color='white')

plt.tight_layout()
plt.show()  # Display confusion matrix plot

# Print Confusion Matrix values
print("Confusion Matrix:")
print(cf_matrix)

# Determine if it's binary or multi-class
is_binary = len(classes) == 2  # If there are only two classes, it's binary classification

# Compute ROC Curve and AUC
lb = LabelBinarizer()
all_labels_bin = lb.fit_transform(all_labels)  # Convert labels to binary format

fpr = dict()
tpr = dict()
roc_auc = dict()

if is_binary:
    # For binary classification, we only need the positive class (class 1)
    fpr, tpr, _ = roc_curve(all_labels_bin, np.array(all_preds_prob)[:, 1])  # Get probabilities for class 1
    roc_auc = auc(fpr, tpr)
else:
    # For multi-class classification, compute ROC for each class
    for i in range(len(classes)):
        fpr[i], tpr[i], _ = roc_curve(all_labels_bin[:, i], np.array(all_preds_prob)[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

# Print ROC values
print("\nROC Values:")
if is_binary:
    print(f'Class 1: AUC = {roc_auc:.2f}')
else:
    for i in range(len(classes)):
        print(f'Class {classes[i]}: AUC = {roc_auc[i]:.2f}')

# Plot ROC curve
plt.figure(figsize=(8, 6))
if is_binary:
    plt.plot(fpr, tpr, label=f'Class 1 (AUC = {roc_auc:.2f})')
else:
    for i in range(len(classes)):
        plt.plot(fpr[i], tpr[i], label=f'Class {classes[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line (no discrimination)
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()  # Display ROC curve plot
# Out:
# <ipython-input-8-eac103c8114b>:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/heatmaps_model.pth'))
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       761
#            1       0.97      0.89      0.93       786
#
#     accuracy                           0.93      1547
#    macro avg       0.93      0.93      0.93      1547
# weighted avg       0.93      0.93      0.93      1547
# Confusion Matrix:
# [[739  22]
#  [ 90 696]]
#
# ROC Values:
# Class 1: AUC = 0.98
